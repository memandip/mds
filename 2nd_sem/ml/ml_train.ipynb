# %% [markdown]
# # ML Train Model

# %%
# %pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from gymnasium) (2.2.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from gymnasium) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from gymnasium) (0.0.4)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import gymnasium as gym

# set seed
SEED = 106

# set discount factor
GAMMA = 0.8

# %%
# Initialize the FrozenLake environment
env = gym.make("FrozenLake-v1", map_name="4x4", is_slippery=False, render_mode="ansi")

# %%
env.reset(seed=SEED)
print(env.render())
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
