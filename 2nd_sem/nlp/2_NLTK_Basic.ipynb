# %% [markdown]
# ## NLTK Essentials
# Doing all the NLP related task are possible with core python.
# But it is time consuming and takes lots of resources and need extensive computational skills.
#
# The work are made easier with the libraries such as NLTK.
#
# - NLTK is the module of python that helps for NLP

# %%
# install
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (3.9.1)
# Requirement already satisfied: click in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from nltk) (2025.7.34)
# Requirement already satisfied: tqdm in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from nltk) (4.67.1)

# %% [markdown]
# ### NLTK Data Set
# - import nltk
# - download the data set
# - Dataset: are the collection of the text, lexicon, corpora (body of the text)
#
# `nltk.download()`

# %%
import nltk

# %%
# nltk.download()
# nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mandipchaudhary/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/mandipchaudhary/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %% [markdown]
# ## Explore dataset / corpus

# %%
from nltk.corpus import movie_reviews

# %%
# movie_reviews.fileids()
len(movie_reviews.fileids())
# Out:
# 2000

# %%
print(type(movie_reviews.fileids()))
movie_reviews.fileids()[:5]
# Out:
# <class 'list'>
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt']

# %%
print(movie_reviews.raw('neg/cv000_29416.txt'))
# Out:
# plot : two teen couples go to a church party , drink and then drive .
# they get into an accident .
# one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares .
# what's the deal ?
# watch the movie and " sorta " find out . . .
# critique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package .
# which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn't snag this one correctly .
# they seem to have taken this pretty neat concept , but executed it terribly .
# so what are the problems with the movie ?
# well , its main problem is that it's simply too jumbled .
# it starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what's going on .
# there are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained .
# now i personally don't mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film's biggest problem .
# it's obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes .
# and do they make things entertaining , thrilling or even engaging , in the meantime ?
# not really .
# the sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn't the make the film all that more entertaining .
# i guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding .
# i mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy ! !
# okay , we get it . . . there
# are people chasing her and we don't know who they are .
# do we really need to see it over and over again ?
# how about giving us different scenes offering further insight into all of the strangeness going down in the movie ?
# apparently , the studio took this film away from its director and chopped it up themselves , and it shows .
# there might've been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense .
# the actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood .
# but my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character's unraveling .
# overall , the film doesn't stick because it doesn't entertain , it's confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it .
# oh , and by the way , this is not a horror or teen slasher flick . . . it's
# just packaged to look that way because someone is apparently assuming that the genre is still hot with the kids .
# it also wrapped production two years ago and has been sitting on the shelves ever since .
# whatever . . . skip
# it !
# where's joblo coming from ?
# a nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 ) - lost highway ( 10/10 ) - memento ( 10/10 ) - the others ( 9/10 ) - stir of echoes ( 8/10 )

# %% [markdown]
# ### Analyzing text statistics
# Those really help explore the fundamental characteristics of the text data.
#
# ext statistics visualizations are simple but very insightful techniques.
#
# They include:
#
# - word frequency analysis,
# - sentence length analysis,
# - average word length analysis, etc.
#
# Those really help **explore the fundamental characteristics** of the text data.
#
# To do so, we will be mostly using histograms (continuous data) and bar charts (categorical data).

# %% [markdown]
# #### Word frequency analysis

# %%
text = movie_reviews.raw('neg/cv000_29416.txt')
print(text)
# Out:
# plot : two teen couples go to a church party , drink and then drive .
# they get into an accident .
# one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares .
# what's the deal ?
# watch the movie and " sorta " find out . . .
# critique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package .
# which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn't snag this one correctly .
# they seem to have taken this pretty neat concept , but executed it terribly .
# so what are the problems with the movie ?
# well , its main problem is that it's simply too jumbled .
# it starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what's going on .
# there are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained .
# now i personally don't mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film's biggest problem .
# it's obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes .
# and do they make things entertaining , thrilling or even engaging , in the meantime ?
# not really .
# the sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn't the make the film all that more entertaining .
# i guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding .
# i mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy ! !
# okay , we get it . . . there
# are people chasing her and we don't know who they are .
# do we really need to see it over and over again ?
# how about giving us different scenes offering further insight into all of the strangeness going down in the movie ?
# apparently , the studio took this film away from its director and chopped it up themselves , and it shows .
# there might've been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense .
# the actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood .
# but my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character's unraveling .
# overall , the film doesn't stick because it doesn't entertain , it's confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it .
# oh , and by the way , this is not a horror or teen slasher flick . . . it's
# just packaged to look that way because someone is apparently assuming that the genre is still hot with the kids .
# it also wrapped production two years ago and has been sitting on the shelves ever since .
# whatever . . . skip
# it !
# where's joblo coming from ?
# a nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 ) - lost highway ( 10/10 ) - memento ( 10/10 ) - the others ( 9/10 ) - stir of echoes ( 8/10 )

# %%
# tokens
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mandipchaudhary/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/mandipchaudhary/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mandipchaudhary/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = text.lower()
all_tokens = word_tokenize(text)
print(len(all_tokens))
print(all_tokens)
# Out:
# 841
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party', ',', 'drink', 'and', 'then', 'drive', '.', 'they', 'get', 'into', 'an', 'accident', '.', 'one', 'of', 'the', 'guys', 'dies', ',', 'but', 'his', 'girlfriend', 'continues', 'to', 'see', 'him', 'in', 'her', 'life', ',', 'and', 'has', 'nightmares', '.', 'what', "'s", 'the', 'deal', '?', 'watch', 'the', 'movie', 'and', '``', 'sorta', '``', 'find', 'out', '.', '.', '.', 'critique', ':', 'a', 'mind-fuck', 'movie', 'for', 'the', 'teen', 'generation', 'that', 'touches', 'on', 'a', 'very', 'cool', 'idea', ',', 'but', 'presents', 'it', 'in', 'a', 'very', 'bad', 'package', '.', 'which', 'is', 'what', 'makes', 'this', 'review', 'an', 'even', 'harder', 'one', 'to', 'write', ',', 'since', 'i', 'generally', 'applaud', 'films', 'which', 'attempt', 'to', 'break', 'the', 'mold', ',', 'mess', 'with', 'your', 'head', 'and', 'such', '(', 'lost', 'highway', '&', 'memento', ')', ',', 'but', 'there', 'are', 'good', 'and', 'bad', 'ways', 'of', 'making', 'all', 'types', 'of', 'films', ',', 'and', 'these', 'folks', 'just', 'did', "n't", 'snag', 'this', 'one', 'correctly', '.', 'they', 'seem', 'to', 'have', 'taken', 'this', 'pretty', 'neat', 'concept', ',', 'but', 'executed', 'it', 'terribly', '.', 'so', 'what', 'are', 'the', 'problems', 'with', 'the', 'movie', '?', 'well', ',', 'its', 'main', 'problem', 'is', 'that', 'it', "'s", 'simply', 'too', 'jumbled', '.', 'it', 'starts', 'off', '``', 'normal', '``', 'but', 'then', 'downshifts', 'into', 'this', '``', 'fantasy', '``', 'world', 'in', 'which', 'you', ',', 'as', 'an', 'audience', 'member', ',', 'have', 'no', 'idea', 'what', "'s", 'going', 'on', '.', 'there', 'are', 'dreams', ',', 'there', 'are', 'characters', 'coming', 'back', 'from', 'the', 'dead', ',', 'there', 'are', 'others', 'who', 'look', 'like', 'the', 'dead', ',', 'there', 'are', 'strange', 'apparitions', ',', 'there', 'are', 'disappearances', ',', 'there', 'are', 'a', 'looooot', 'of', 'chase', 'scenes', ',', 'there', 'are', 'tons', 'of', 'weird', 'things', 'that', 'happen', ',', 'and', 'most', 'of', 'it', 'is', 'simply', 'not', 'explained', '.', 'now', 'i', 'personally', 'do', "n't", 'mind', 'trying', 'to', 'unravel', 'a', 'film', 'every', 'now', 'and', 'then', ',', 'but', 'when', 'all', 'it', 'does', 'is', 'give', 'me', 'the', 'same', 'clue', 'over', 'and', 'over', 'again', ',', 'i', 'get', 'kind', 'of', 'fed', 'up', 'after', 'a', 'while', ',', 'which', 'is', 'this', 'film', "'s", 'biggest', 'problem', '.', 'it', "'s", 'obviously', 'got', 'this', 'big', 'secret', 'to', 'hide', ',', 'but', 'it', 'seems', 'to', 'want', 'to', 'hide', 'it', 'completely', 'until', 'its', 'final', 'five', 'minutes', '.', 'and', 'do', 'they', 'make', 'things', 'entertaining', ',', 'thrilling', 'or', 'even', 'engaging', ',', 'in', 'the', 'meantime', '?', 'not', 'really', '.', 'the', 'sad', 'part', 'is', 'that', 'the', 'arrow', 'and', 'i', 'both', 'dig', 'on', 'flicks', 'like', 'this', ',', 'so', 'we', 'actually', 'figured', 'most', 'of', 'it', 'out', 'by', 'the', 'half-way', 'point', ',', 'so', 'all', 'of', 'the', 'strangeness', 'after', 'that', 'did', 'start', 'to', 'make', 'a', 'little', 'bit', 'of', 'sense', ',', 'but', 'it', 'still', 'did', "n't", 'the', 'make', 'the', 'film', 'all', 'that', 'more', 'entertaining', '.', 'i', 'guess', 'the', 'bottom', 'line', 'with', 'movies', 'like', 'this', 'is', 'that', 'you', 'should', 'always', 'make', 'sure', 'that', 'the', 'audience', 'is', '``', 'into', 'it', '``', 'even', 'before', 'they', 'are', 'given', 'the', 'secret', 'password', 'to', 'enter', 'your', 'world', 'of', 'understanding', '.', 'i', 'mean', ',', 'showing', 'melissa', 'sagemiller', 'running', 'away', 'from', 'visions', 'for', 'about', '20', 'minutes', 'throughout', 'the', 'movie', 'is', 'just', 'plain', 'lazy', '!', '!', 'okay', ',', 'we', 'get', 'it', '.', '.', '.', 'there', 'are', 'people', 'chasing', 'her', 'and', 'we', 'do', "n't", 'know', 'who', 'they', 'are', '.', 'do', 'we', 'r ...

# %%
sents = sent_tokenize (text)
print(len(sents))
sents
# Out:
# 44
# ['plot : two teen couples go to a church party , drink and then drive .',
#  'they get into an accident .',
#  'one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares .',
#  "what's the deal ?",
#  'watch the movie and " sorta " find out .',
#  '.',
#  '.',
#  'critique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package .',
#  "which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn't snag this one correctly .",
#  'they seem to have taken this pretty neat concept , but executed it terribly .',
#  'so what are the problems with the movie ?',
#  "well , its main problem is that it's simply too jumbled .",
#  'it starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what\'s going on .',
#  'there are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained .',
#  "now i personally don't mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film's biggest problem .",
#  "it's obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes .",
#  'and do they make things entertaining , thrilling or even engaging , in the meantime ?',
#  'not really .',
#  "the sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn't the make the film all that more entertaining .",
#  'i guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding .',
#  'i mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy !',
#  '!',
#  'okay , we get it .',
#  '.',
#  '.',
#  "there \nare people chasing her and we don't know who they are .",
#  'do we really need to see it over and over again ?',
#  'how about giving us different scenes offering further insight into all of the strangeness going down in the movie ?',
#  'apparently , the studio took this film away from its director and chopped it up themselves , and it shows .',
#  'there might\'ve been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense .',
#  'the actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood .',
#  "but my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character's unraveling .",
#  "overall , the film doesn't stick because it doesn't entertain , it's confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it .",
#  'oh , and by the way , this is not a horror or teen slasher flick .',
#  '.',
#  '.',
#  "it's \njust packaged to look that way because someone is apparently assuming that the genre is still hot with the kids .",
#  'it also wrapped production two years ago and has been sitting on the shelves ever since .',
#  'whatever .',
#  '.',
#  '.',
#  'skip \nit !',
#  "where's joblo coming from ?",
#  'a nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 ) - lost highway ( 10/10 ) - memento ( 10/10 ) - the others ( 9/10 ) - stir of echoes ( 8/10 )']

# %%
# calculate word frequency
f_dist = nltk.FreqDist(all_tokens)
f_dist.most_common(20)
# Out:
# [(',', 44),
#  ('the', 38),
#  ('.', 34),
#  ('it', 25),
#  ('and', 20),
#  ('to', 16),
#  ('of', 16),
#  ('a', 14),
#  ('that', 13),
#  ('are', 13),
#  ('is', 12),
#  ('but', 10),
#  ('``', 10),
#  ('this', 10),
#  ('there', 10),
#  ("'s", 9),
#  ('(', 9),
#  (')', 9),
#  ('in', 8),
#  ('i', 7)]

# %%
f_dist.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### Removal of the stop words

# %%
from nltk.corpus import stopwords
import string
# check what languages are included
print(stopwords.fileids())
# Out:
# ['albanian', 'arabic', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'tamil', 'turkish']

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {"it's", 'don', "hadn't", 'very', "i've", 'd', 'do', 'once', 'shouldn', 'hasn', "she'll", 'itself', 'any', 'its', 'most', "needn't", 'y', "shouldn't", 'into', 'same', "they've", "he'll", 'they', 'here', 'didn', 'only', 've', "he's", 'you', 'herself', 'm', 'he', "weren't", 'down', 'me', "hasn't", 's', 'yourselves', 'mightn', 'but', 'by', "shan't", 'and', "they're", "mightn't", 'more', "she's", 'some', 'an', "wasn't", "aren't", "you've", 'i', 'ours', "you'll", "we're", 'will', 'above', 'yours', 'haven', 't', "it'd", 'when', 'theirs', 'up', 'then', 'too', 'had', 'all', 'just', 'for', 'themselves', 'against', 'her', 'weren', 'few', 'a', "i'm", 'over', 'between', 'further', 'on', "mustn't", 'is', 'who', 'himself', 'it', 'myself', "doesn't", 'nor', 'those', "i'll", 'no', 'ourselves', "they'll", 'ain', 'o', 'than', 'mustn', 'to', "you're", 'were', 'that', 'did', 'whom', 'my', 'aren', 'how', 'before', 're', 'which', 'with', 'as', 'during', 'through', 'at', 'of', "i'd", "won't", 'needn', 'about', 'has', 'other', "couldn't", 'both', 'was', "don't", "should've", 'should', 'hadn', 'hers', 'not', 'what', 'now', "they'd", 'being', "we'll", 'again', 'if', "she'd", "didn't", 'below', 'can', 'am', 'while', "that'll", 'there', 'are', 'll', 'after', 'doing', 'have', 'until', 'we', 'wouldn', 'because', "wouldn't", 'having', 'why', 'each', 'their', 'out', 'such', "isn't", 'them', "we'd", 'does', 'our', "we've", 'yourself', 'be', 'couldn', 'shan', 'where', 'own', 'doesn', 'his', 'won', 'wasn', 'this', 'these', 'so', 'in', 'your', "he'd", "you'd", 'been', 'him', 'she', "haven't", 'from', 'the', 'ma', 'under', 'off', 'or', "it'll", 'isn'}

# %%
# prepare the list of the words to be filtered
punctuations =  set(string.punctuation)
other_characters = [':','"','-', "''",'``',"-","--"]

filter_words = list(stop_words) + list(punctuations) + list(other_characters)
print(filter_words)
# Out:
# ["it's", 'don', "hadn't", 'very', "i've", 'd', 'do', 'once', 'shouldn', 'hasn', "she'll", 'itself', 'any', 'its', 'most', "needn't", 'y', "shouldn't", 'into', 'same', "they've", "he'll", 'they', 'here', 'didn', 'only', 've', "he's", 'you', 'herself', 'm', 'he', "weren't", 'down', 'me', "hasn't", 's', 'yourselves', 'mightn', 'but', 'by', "shan't", 'and', "they're", "mightn't", 'more', "she's", 'some', 'an', "wasn't", "aren't", "you've", 'i', 'ours', "you'll", "we're", 'will', 'above', 'yours', 'haven', 't', "it'd", 'when', 'theirs', 'up', 'then', 'too', 'had', 'all', 'just', 'for', 'themselves', 'against', 'her', 'weren', 'few', 'a', "i'm", 'over', 'between', 'further', 'on', "mustn't", 'is', 'who', 'himself', 'it', 'myself', "doesn't", 'nor', 'those', "i'll", 'no', 'ourselves', "they'll", 'ain', 'o', 'than', 'mustn', 'to', "you're", 'were', 'that', 'did', 'whom', 'my', 'aren', 'how', 'before', 're', 'which', 'with', 'as', 'during', 'through', 'at', 'of', "i'd", "won't", 'needn', 'about', 'has', 'other', "couldn't", 'both', 'was', "don't", "should've", 'should', 'hadn', 'hers', 'not', 'what', 'now', "they'd", 'being', "we'll", 'again', 'if', "she'd", "didn't", 'below', 'can', 'am', 'while', "that'll", 'there', 'are', 'll', 'after', 'doing', 'have', 'until', 'we', 'wouldn', 'because', "wouldn't", 'having', 'why', 'each', 'their', 'out', 'such', "isn't", 'them', "we'd", 'does', 'our', "we've", 'yourself', 'be', 'couldn', 'shan', 'where', 'own', 'doesn', 'his', 'won', 'wasn', 'this', 'these', 'so', 'in', 'your', "he'd", "you'd", 'been', 'him', 'she', "haven't", 'from', 'the', 'ma', 'under', 'off', 'or', "it'll", 'isn', ',', '[', '-', '%', '`', '~', '?', '&', '=', '+', '<', "'", '}', '#', '.', '@', '"', '_', ':', '$', '(', '>', '\\', '!', ';', ')', '^', '{', '/', ']', '*', '|', ':', '"', '-', "''", '``', '-', '--']

# %%
tokens = []
for token in all_tokens:
    if token not in filter_words:
        tokens.append(token)
print(len(tokens))

# using list comprehention
tokens2 = [word for word in all_tokens if word not in filter_words]
print(len(tokens2))

# using lambda
tokens3 = list(filter(lambda word: word not in filter_words, all_tokens))
print(len(tokens3))
# tokens
# Out:
# 348
# 348
# 348

# %%
# now apply the freq analysis
f_dist = nltk.FreqDist(tokens)
f_dist.most_common(20)
f_dist.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
f_dist.plot(50, cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %% [markdown]
# #### Word cloud

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from wordcloud) (2.2.5)
# Requirement already satisfied: pillow in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from wordcloud) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-macosx_11_0_arm64.whl (167 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10)
wordcloud.generate_from_frequencies(f_dist)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# #### Using pandas for other frequency analysis

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize
from nltk.corpus import movie_reviews

# %%
text = movie_reviews.raw('neg/cv000_29416.txt')
text = text.lower()
text = sent_tokenize(text,language="english")
text
# Out:
# ['plot : two teen couples go to a church party , drink and then drive .',
#  'they get into an accident .',
#  'one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares .',
#  "what's the deal ?",
#  'watch the movie and " sorta " find out .',
#  '.',
#  '.',
#  'critique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package .',
#  "which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn't snag this one correctly .",
#  'they seem to have taken this pretty neat concept , but executed it terribly .',
#  'so what are the problems with the movie ?',
#  "well , its main problem is that it's simply too jumbled .",
#  'it starts off " normal " but then downshifts into this " fantasy " world in which you , as an audience member , have no idea what\'s going on .',
#  'there are dreams , there are characters coming back from the dead , there are others who look like the dead , there are strange apparitions , there are disappearances , there are a looooot of chase scenes , there are tons of weird things that happen , and most of it is simply not explained .',
#  "now i personally don't mind trying to unravel a film every now and then , but when all it does is give me the same clue over and over again , i get kind of fed up after a while , which is this film's biggest problem .",
#  "it's obviously got this big secret to hide , but it seems to want to hide it completely until its final five minutes .",
#  'and do they make things entertaining , thrilling or even engaging , in the meantime ?',
#  'not really .',
#  "the sad part is that the arrow and i both dig on flicks like this , so we actually figured most of it out by the half-way point , so all of the strangeness after that did start to make a little bit of sense , but it still didn't the make the film all that more entertaining .",
#  'i guess the bottom line with movies like this is that you should always make sure that the audience is " into it " even before they are given the secret password to enter your world of understanding .',
#  'i mean , showing melissa sagemiller running away from visions for about 20 minutes throughout the movie is just plain lazy !',
#  '!',
#  'okay , we get it .',
#  '.',
#  '.',
#  "there \nare people chasing her and we don't know who they are .",
#  'do we really need to see it over and over again ?',
#  'how about giving us different scenes offering further insight into all of the strangeness going down in the movie ?',
#  'apparently , the studio took this film away from its director and chopped it up themselves , and it shows .',
#  'there might\'ve been a pretty decent teen mind-fuck movie in here somewhere , but i guess " the suits " decided that turning it into a music video with little edge , would make more sense .',
#  'the actors are pretty good for the most part , although wes bentley just seemed to be playing the exact same character that he did in american beauty , only in a new neighborhood .',
#  "but my biggest kudos go out to sagemiller , who holds her own throughout the entire film , and actually has you feeling her character's unraveling .",
#  "overall , the film doesn't stick because it doesn't entertain , it's confusing , it rarely excites and it feels pretty redundant for most of its runtime , despite a pretty cool ending and explanation to all of the craziness that came before it .",
#  'oh , and by the way , this is not a horror or teen slasher flick .',
#  '.',
#  '.',
#  "it's \njust packaged to look that way because someone is apparently assuming that the genre is still hot with the kids .",
#  'it also wrapped production two years ago and has been sitting on the shelves ever since .',
#  'whatever .',
#  '.',
#  '.',
#  'skip \nit !',
#  "where's joblo coming from ?",
#  'a nightmare of elm street 3 ( 7/10 ) - blair witch 2 ( 7/10 ) - the crow ( 9/10 ) - the crow : salvation ( 4/10 ) - lost highway ( 10/10 ) - memento ( 10/10 ) - the others ( 9/10 ) - stir of echoes ( 8/10 )']

# %%
text_dict = {'sent': text}
df = pd.DataFrame.from_dict(dict(text_dict))
df.head(10)
# Out:
#                                                 sent
# 0  plot : two teen couples go to a church party ,...
# 1                        they get into an accident .
# 2  one of the guys dies , but his girlfriend cont...
# 3                                  what's the deal ?
# 4           watch the movie and " sorta " find out .
# 5                                                  .
# 6                                                  .
# 7  critique : a mind-fuck movie for the teen gene...
# 8  which is what makes this review an even harder...
# 9  they seem to have taken this pretty neat conce...

# %%
# number of characters present in each sentence
df['sent'].str.len().hist()
# Out:
# <Axes: >

# %%
# the number of words appearing in each sent
df['sent'].str.split().\
    map(lambda x: len(x)).\
    hist()
# Out:
# <Axes: >
