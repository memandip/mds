# %% [markdown]
# # Building the NER for Nepali

# %% [markdown]
# ### Dataset Preparation

# %% [markdown]
# We can train our own model for NER using spacy
#
# For this we need a notated data in spacy format.
#
# There are tools that can generate that particular formats:
#
# - https://tecoholic.github.io/ner-annotator/

# %%
# %pip install spacy nltk scikit-learn
# Out:
# Requirement already satisfied: spacy in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (3.8.7)
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (2.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.8.3)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: wrapt in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.3)
# Collecting joblib (from nltk)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.7.34-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/admin/Desktop/MDS/.venv/lib/python3.13/site-packages (from jinja2->spacy) (3.0.2)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading scikit_learn-1.7.1-cp313-cp313-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 10.6 MB/s  0:00:00 10.8 MB/s eta 0:00:01
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading regex-2025.7.34-cp313-cp313-macosx_11_0_arm64.whl (285 kB)
# Downloading scipy-1.16.1-cp313-cp313-macosx_14_0_arm64.whl (20.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 11.4 MB/s  0:00:01 11.5 MB/s eta 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, regex, joblib, scikit-learn, nltk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [nltk]━━━━━━ 5/6 [nltk] [scikit-learn]
# Successfully installed joblib-1.5.1 nltk-3.9.1 regex-2025.7.34 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#load annotated data

import json
with open('spacy-ner/train-ner-annotations.json', 'r') as f:
    data = json.load(f)

# %%
data
# Out:
# {'classes': ['PERSON', 'PLACE', 'ORGANIZATION', 'POST'],
#  'annotations': [['संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डेले विमान दुर्घटनाबारे सरकार गम्भीर रहेको बताएका छन् । गम्भीर रूपमा मन्त्रालय अध्ययनमा लागेको र चाँडै कारबाही लगायतका निर्णय लिइने उनले संसदीय समितिलाई जानकारी दिएका छन् । ',
#    {'entities': [[28, 41, 'POST'],
#      [42, 56, 'PERSON'],
#      [189, 204, 'ORGANIZATION']]}],
#   ['प्रतिनिधिसभा अन्तर्गतको अन्तर्राष्ट्रिय सम्बन्ध र पर्यटन समितिको बिहीबारको बैठकमा सांसदहरूले विमान र हेलिकप्टर दुर्घनाबारे सोधेका प्रश्नको जवाफ दिने क्रममा मन्त्री पाण्डेले कानुन र संवैधानिक रूपमा परिपक्व निर्णय लिन लागिएको बताएका हुन् ।',
#    {'entities': [[0, 23, 'ORGANIZATION'],
#      [24, 64, 'ORGANIZATION'],
#      [156, 163, 'POST'],
#      [164, 172, 'PERSON']]}],
#   ["'मातहतका निकायलाई कारबाही गर्ने सम्बन्धमा घोत्लिएका छौं । खासगरी सौर्य एयरलाइन्सको विमान दुर्घटनापछि हामी घोत्लिएका छौं,' मन्त्री पाण्डेले भने, 'म के चाहन्न भने मन्त्रीको पहलकदमीमा कुनै निर्णय होस् र अर्को कुनै बाटोबाट पुनर्स्थापति होस् र मन्त्री त्यहीँ बसिरहोस्, मेरो निर्णयमा चुनौती जुनसुकै निकायबाट आओस् त्यो निकायबाट चुनौती आइसकेपछि अथवा बदर भइसकेपछि त्यो मन्त्रीले त्यही बसिरहने नैतिक अधिकार हुन्न । मन्त्रीले गरेको निर्णय संवैधानिक कानुनी हिसाबले सम्परीक्षण भएको हुनुपर्छ । सर्वस्वीकृत हुनुपर्छ । होइन भने मन्त्रीले त्यहाँ बस्ने नैतिक अधिकार राख्दैन त्यहीअनुसार छलफल गरिरहेका छौं । चाडै सभापतिमार्फत यो समितिले पनि थाहा पाउनेछ र मुलुकले थाहा पाउनेछ भन्ने विश्वास दिलाउन चाहन्छु ।'",
#    {'entities': [[65, 82, 'ORGANIZATION'],
#      [130, 138, 'PERSON'],
#      [405, 414, 'POST'],
#      [512, 521, 'POST'],
#      [593, 605, 'POST']]}],
#   ["समितिमा सांसदहरूले जिम्मेवार अधिकारीहरूलाई निलम्बन गरेर मात्रै छानबिनको माग गरेका थिए । नैतिकताका आधारमा पनि पदमा राख्न नहुने उनीहरूको भनाइ थियो । यस विषयमा मन्त्री पाण्डेले भने, 'केही विषयहरू निलम्बन लगायतका विषयहरू आएका छन् । नैतिकताको प्रश्न व्यक्तिमा निहित हुन्छ अरु कसैले लाद्ने विषय होइन । मेरो नैतिकताको प्रश्न मैमाथि निहित हुन्छ । अरु कसैको नैतिकताको प्रश्न उसैमा निहीत हुन्छ । लादेर नैतिकता लादिँदैन । कानुनी प्रक्रियासम्मत बाटोबाट जानका लागि अप्ठ्यारा र जटिलता के हुन् खोतलिरहेका छौं ।'",
#    {'entities': [[63, 81, 'ORGANIZATION'],
#      [120, 125, 'POST'],
#      [126, 139, 'PERSON'],
#      [238, 254, 'POST'],
#      [359, 371, 'POST'],
#      [400, 417, 'POST']]}],
#   ['आफूमाथि नैतिकताको प्रश्न उठेमा एक क्षण पनि मन्त्री पदमा नबस्ने पाण्डेको भनाइ थियो ।',
#    {'entities': [[43, 50, 'POST'], [63, 71, 'PERSON']]}],
#   ['संस्कृति, पर्यटन र नागरिक उड्डयन क्षेत्रमा तमाम विकृति रहेको बताउँदै मन्त्री पाण्डेले तिनको समाधानमा आफू लागेको बताए ।',
#    {'entities': [[0, 8, 'ORGANIZATION'],
#      [69, 76, 'POST'],
#      [77, 85, 'PERSON']]}],
#   ['उक्त हेलिकप्टर क्याप्टेन अरुण मल्लले उडाएका थिए भने ४ चिनियाँ पर्यटक स्याफ्रुबेंसी लगिँदै थियो । एयर डाइनेस्टीको ४ चिनियाँ पर्यटक छाडेर फेरि विदेशी नागरिक ल्याउने तालिका बनाएको थियो ।',
#    {'entities': [[15, 24, 'POST'],
#      [25, 36, 'PERSON'],
#      [69, 82, 'PLACE'],
#      [97, 112, 'ORGANIZATION']]}],
#   ['बुधबार दिउँसो दुर्घटना भएको एयर डाइनेस्टीको हेलिकप्टरका क्याप्टेन र ४ चिनियाँ पर्यटकको मृत्यु भएको छ । मृत्यु हुनेमा क्याप्टेन अरुण मल्ल र चिनियाँ नागरिकहरू जुताड ताङ, ताइ ली, जेमिङ जी र यीयाड वु रहेका छन् । मृत्यु हुनेमा ४ पुरुष र १ महिला छन् ।',
#    {'entities': [[28, 43, 'ORGANIZATION'],
#      [56, 77, 'PERSON'],
#      [127, 136, 'PERSON'],
#      [157, 166, 'PERSON'],
#      [168, 174, 'PERSON'],
#      [176, 184, 'PERSON'],
#      [187, 195, 'PERSON']]}],
#   ['प्रत्यक्षदर्शीका अनुसार हेलिकप्टर रुखमा ठोक्किएर आगो लाग्दै झरेको थियो ।',
#    {'entities': [[0, 16, 'PERSON']]}],
#   ['दुर्घटनाको कारणबारे पत्ता लागेको छैन । उक्त उडान हुँदा भिजिविलिटी ५ किलोमिटर तथा सामान्य रहेको थियो ।',
#    {'entities': []}],
#   ['घटनाको खबर आउनेवित्तिसकै खोजीमा अर्को हेलिकोप्टर पठाइएको थियो । त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलबाट प्रभु एयरको हेलिकोप्टार परिचालन गरिएको थियो ।',
#    {'entities': [[64, 101, 'PLACE'], [102, 113, 'ORGANIZATION']]}],
#   ["गुर्जेभन्ज्याङको अस्थायी प्रहरी पोस्टका हवल्दार राजन खत्रीका अनुसार ४ पुरुष १ महिलाको शव फेला परेको छ । उनले भने, 'हेलिकप्टर खोल्सामा परेको छ । शव निकाल्न गाह्रो भइरहेको छ ।'",
#    {'entities': [[0, 16, 'PLACE'], [40, 47, 'POST'], [48, 60, 'PERSON']]}],
#   ['काठमाडौँ — बुधबार दिउँसो दुर्घटना भएको एयर डाइनेस्टीको हेलिकप्टरमा सवार पाँचै जनाको ज्यान गएको छ । बुधबार १ बजेर १४ मिनेटमा त्रिभुवन विमानस्थलबाट ४ चिनियाँ यात्रु लिएर उडेको उक्त हेलिकप्टर नुवाकोट शिवपुरी गाउँपालिका-७ सूर्यचौर डाँडा र गुर्जेभन्ज्याङको बीचमा दुर्घटना हुँदा हेलिकप्टरमा सवार पाँचै जनाको ज्यान गएको हो । ',
#    {'entities': [[39, 54, 'ORGANIZATION'],
#      [124, 145, 'PLACE'],
#      [189, 196, 'PLACE'],
#      [197, 204, 'PLACE'],
#      [218, 232, 'PLACE'],
#      [235, 251, 'PLACE']]}],
#   ['काठमाडौँ — एयर डाइनेस्टीको ९ एन-एजेडी रजिस्ट्रेसन रहेको हेलिकप्टर त्रिभुवन विमानस्थलबाट उडेको तीन मिनेटपछि नै काठमाडौं विमानस्थलमा रहेको टावरसँग सम्पर्क विच्छेद भएको थियो ।',
#    {'entities': [[11, 26, 'ORGANIZATION'],
#      [66, 87, 'PLACE'],
#      [110, 130, 'PLACE']]}],
#   ['नेपाल नागरिक उडड्यन प्राधिकरण, खोज तथा उद्धार समन्वय केन्द्रले बुधबार जारी गरेको विज्ञप्तिअनुसार सो हेलिकप्टर उडान गरेको ३ मिनेट पछि काठमाडौं टावरसँग सम्पर्क विच्छेद भई नुवाकोटको शिवपुरी गाउँपालिका-७ सूर्याचौरमा दुर्घटनामा परेको हो । दुर्घटनामा चार जना यात्रुसहित क्याप्टेनको मृत्यु भएको छ । ',
#    {'entities': [[0, 29, 'ORGANIZATION'],
#      [31, 62, 'ORGANIZATION'],
#      [169, 178, 'PLACE'],
#      [179, 186, 'PLACE'],
#      [200, 211, 'PLACE']]}],
#   ['काठमाडौँ — प्रधानमन्त्री केपी शर्मा ओलीले नुवाकोटमा बुधबार दिउँसो एयर डाइनेष्टीको हेलिकप्टर दुर्घटना भएकोप्रति दुःख व्यक्त गरेका छन् । ',
#    {'entities': [[11, 24, 'POST'],
#      [25, 41, 'PERSON'],
#      [42, 51, 'PLACE'],
#      [66, 81, 'ORGANIZATION']]}],
#   ['सिंहदरबारस्थित उपत्यका मेयर्स फोरमका पदाधिकारीसँग पूर्व निर्धारित भेटघाटमा रहेका प्रधानमन्त्री ओलीले दुर्घटनाको खबर थाहा पाएपछि भारी मनका साथ नगरप्रमुखहरुसँग प्रस्तुत हुँदै भेटघाटलाई संक्षिप्त बनाएका थिए । ',
#    {'entities': [[0, 14, 'PLACE'],
#      [15, 36, 'ORGANIZATION'],
#      [81, 94, 'POST'],
#      [95, 100, 'PERSON'],
#      [142, 157, 'POST']]}],
#   ['प्रधानमन्त्री ओलीले १४ दिनपछि अर्काे हवाइ दुर्घटना हुनु दुःखद् भएको बताए । उक्त दुर्घटनाका सम्बन्धमा केही बेरपछि मन्त्रिपरिषद्को आकरिस्मक बैठक बस्ने तयारी भएको छ ।',
#    {'entities': [[0, 13, 'POST'],
#      [14, 19, 'PERSON'],
#      [113, 128, 'ORGANIZATION']]}],
#   ['दुर्घटना भएयता सौर्य एयरलाइन्सका कुनै पनि उच्च पदस्थ अधिकारीहरू सान्त्वना दिनसमेत नआएको भन्दै मृतकका आफन्तद्वारा रोष प्रकट',
#    {'entities': [[15, 32, 'ORGANIZATION'], [42, 63, 'POST']]}],
#   ['काठमाडौँ — सौर्य एयरलाइन्सको जहाज दुर्घटनामा मृत्यु भएका १८ जनाको शव पोस्टमार्टम सकिएको छ\u202f। शव पहिचान कार्य शुक्रबार बिहान सुरु गर्ने र चिनिएका शव परिवारलाई बुझाउने त्रिवि शिक्षण अस्पतालको तयारी छ\u202f। मृतकका परिवारजन भने बिमा र एयरलाइन्सले दिने क्षतिपूर्तिको टुंगो नलागेसम्म शव नबुझ्ने अडानमा छन्\u202f। ',
#    {'entities': [[11, 28, 'ORGANIZATION'], [165, 188, 'ORGANIZATION']]}],
#   ['त्रिवि शिक्षण अस्पताल महाराजगन्जका फरेन्सिक विभाग प्रमुख डा. गोपाल चौधरीका अनुसार १८ शवमध्ये एक महिला र एक बालकको शव पहिचानका लागि कुनै समस्या छैन\u202f। ‘अन्य १२ शवलाई परिवारले दिएको विवरणअनुसार पहिचान गर्न सकिन्छ जस्तो लाग्छ,’ उनले भने, ‘चार वटा शव भने आगोले डढेका कारण पहिचान गर्न कठिन हुन सक्छ\u202f।’',
#    {'entities': [[0, 34, 'ORGANIZATION'],
#      [35, 49, 'ORGANIZATION'],
#      [50, 56, 'POST'],
#      [57, 60, 'POST'],
#      [61, 74, 'PERSON']]}],
#   ['डा. चौधरीका अनुसार लुगा, बोकेका ग्याजेट, शरीरमा रहेको ट्याटु वा चोटपटकबारे परिवारले दिएको विवरणका आधारमा शव पहिचान गरिन्छ\u202f। शल्यक्रिया गरेको भए त्यसको विवरणका आधारमा चिन्न सहज हुन्छ\u202f। कसैले दाँतको उपचार गराएको भए त्यसको विवरणबाट शव चिन्न सजिलो हुन्छ\u202f। ‘मृतकको दाँत देखिने गरी हाँसेको तस्बिर भए त्यो पनि उपलब्ध गराउन आग्रह गरेका छौं,’ डा. चौधरीले भने, ‘तपाईंहरूले सबै दाँत एकै प्रकारको देखे पनि हामी फरक देख्छौं\u202f। औंठाको छापबाट पनि पहिचान गर्न सकिन्छ\u202f।’',
#    {'entities': [[0, 3, 'POST'],
#      [4, 11, 'PERSON'],
#      [334, 337, 'POST'],
#      [338, 345, 'PERSON']]}],
#   ['डीएनए म्याचिङलाई भने शव पहिचानको अन्तिम विधिका रूपमा मात्रै प्रयोग गरिन्छ\u202f। ‘डीएनए परीक्षणका लागि नमुना संकलन गर्नै पनि कठिन हुन्छ\u202f। त्यसमाथि परीक्षणको नतिजा आउन थोरैमा पनि १२ दिन लाग्छ,’ डा. चौधरीले भने, ‘सकेसम्म डीएनए परीक्षण नगरीकनै शव पहिचान गर्ने विधिलाई प्राथमिकता दिन्छौं\u202f।’',
#    {'entities': [[188, 191, 'POST'], [192, 199, 'PERSON']]}],
#   ['फरेन्सिक विज्ञ डा. चौधरीको नेतृत्वमा पाटन स्वास्थ्य विज्ञान प्रतिष्ठान तथा भक्तपुर जिल्ला अस्पतालका समेत गरी २५ भन्दा बढी डाक्टर र स्वास्थ्यकर्मी पोस्टमार्टममा खटिएका थिए\u202f। डा. चौधरीका अनुसार विमान दुर्घटनामा परेकाले पोस्टमार्टममा मृत्युको कारण खोज्नुपर्दैन तर शव आफन्तजनलाई बुझाउनयोग्य बनाउनै धेरै समय लाग्छ\u202f। ‘भोलि (शुक्रबार) ४ बजेसम्ममा पहिचान भएका शव परिवारलाई बुझाउने कोसिसमा छौं,’ डा. चौधरीले भने\u202f।',
#    {'entities': [[0, 14, 'POST'],
#      [15, 18, 'POST'],
#      [37, 70, 'ORGANIZATION'],
#      [75, 99, 'ORGANIZATION'],
#      [122, 128, 'POST'],
#      [131, 145, 'POST'],
#      [173, 176, 'POST'],
#      [177, 184, 'PERSON'],
#      [387, 390, 'POST'],
#      [391, 398, 'PERSON']]}],
#   ['विमान दुर्घटनामा ज्यान गुमाएकाहरू आफन्त एवं परिवारजनले शव हस्तान्तरण अघि नै बिमा र यथोचित क्षतिपूर्ति रकम टुंगो लगाउन संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डे र सौर्य एयरलाइन्सका एकाउन्टेबल म्यानेजर गोपाल भट्टराईसँग माग गरेका छन्\u202f। मृतकका आफन्तलाई भेट्न मन्त्री पाण्डे र एयरलाइन्सका एकाउन्टेबल म्यानेजर भट्टराई बिहीबार त्रिवि शिक्षण अस्पताल पुगेका थिए\u202f। त्यही बेला मृतकका आफन्तले क्षतिपूर्तिको टुंगो नलागेसम्म शव नबुझ्ने अडान सुनाएका हुन्\u202f।',
#    {'entities': [[146, 159, 'POST'],
#      [160, 172, 'PERSON'],
#      [175, 192, 'ORGANIZATION'],
#      [193, 212, 'POST'],
#      [213, 229, 'PERSON'],
#      [268, 275, 'POST'],
#      [276, 282, 'PERSON'],
#      [297, 316, 'POST'],
#      [317, 324, 'PERSON'],
#      [333, 354, 'ORGANIZATION']]}],
#   ['दुर्घटना भएयता सौर्य एयरलाइन्सका कुनै पनि उच्च पदस्थ अधिकारीहरू आफूहरूलाई भेट्न वा सान्त्वना दिन नआएको बताउँदै उनीहरूले रोष प्रकट गरेका थिए\u202f। ‘एयरलाइन्सकै कर्मचारीहरू दुर्घटनामा पर्दासमेत कम्पनीले एउटा समवेदना सन्देशसमेत निकालेको छैन, भेट्न आउने त परको कुरा,’ एक आफन्तले भने, ‘हामीले के आधारमा कम्पनीका प्रतिनिधि भनेर आएका मान्छेको विश्वास गर्ने\u202f?’',
#    {'entities': [[15, 32, 'ORGANIZATION'],
#      [155, 166, 'POST'],
#      [303, 312, 'POST']]}],
#   ['शिक्षण अस्पतालको फरेन्सिक विभाग रहेको भवनमा जम्मा भएका प्रायः सबै आफन्तले सौर्य एयरलाइन्सले मृतकका परिवारलाई बेवास्ता गरेको आरोप लगाइरहेका थिए\u202f। एयरलाइन्सले आफ्नो मागको उचित सम्बोधन नगरे आपराधिक घटनाका रूपमा छानबिन गर्न प्रहरीमा जाहेरी दिने तयारी पनि रहेको उनीहरूले सुनाए\u202f। छलफलका क्रममा एयरलाइन्सका प्रतिनिधि भट्टराईले दुर्घटनापछि उचित बिमाका लागि कम्पनीले कानुनी प्रतिनिधिमार्फत बिमा कम्पनीसँग छलफल सुरु गरिसकेको जानकारी दिएका थिए\u202f।',
#    {'entities': [[0, 16, 'ORGANIZATION'],
#      [17, 31, 'ORGANIZATION'],
#      [74, 91, 'ORGANIZATION'],
#      [310, 319, 'PERSON'],
#      [358, 380, 'POST']]}],
#   ['‘काममा खटिएकै अवस्थामा हाम्रा कर्मचारीहरू दुर्घटनामा परे भनेर बिमा कम्पनीसँग कुरा गर्न वकिल राखिसकेका छौं\u202f। त्यसमा हामीले जतिसक्दो धेरै बिमा प्राप्त गर्नका लागि कुरा गर्छौं,’ उनले भने, ‘अहिले नै यति रकम भनेर उद्घोष गर्दा हामी तल पर्ने अवस्था आउन सक्छ\u202f। त्यसैले यतिउति रकम नभनौं\u202f।’ उनले सबैले यथोचित क्षतिपूर्ति प्राप्तिको अवस्था सिर्जना गर्न एयरलाइन्स लागिरहेको बताए\u202f।',
#    {'entities': [[30, 41, 'POST'],
#      [57, 76, 'ORGANIZATION'],
#      [87, 91, 'POST']]}],
#   ['मृतकका आफन्तले भने निर्णय गर्न सक्ने एयरलाइन्सका उच्च अधिकारी नै छलफलमा आउनुपर्ने माग गरेका थिए\u202f। मन्त्री पाण्डेले भने शुक्रबार दिउँसोसम्म सहमतिको प्रयास गरिने आश्वासन दिएका छन्\u202f। मन्त्री पाण्डेकै पहलमा शुक्रबार दिउँसो २ बजेअघि मन्त्रालय, एयरलाइन्सका उच्च प्रतिनिधि र मृतकका आफन्तबीच अस्पतालमै छलफल हुने भएको छ\u202f।',
#    {'entities': [[49, 61, 'POST'],
#      [98, 105, 'POST'],
#      [106, 114, 'PERSON'],
#      [180, 187, 'POST'],
#      [228, 237, 'ORGANIZATION'],
#      [251, 265, 'POST']]}],
#   ['विस्तृत परीक्षण र मर्मत (सी–चेक) गर्न काठमाडौंबाट पोखराका लागि उडेको सौर्य एयरलाइन्सको विमान बुधबार त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलमा दुर्घटनामा परेको थियो\u202f। ५० सिट क्षमताको क्यानेडियन ‘बमबार्डियर जेट सीआरजे–२००’ जहाज ‘फेरि फ्लाइट’ (गैरव्यावसायिक उडान) मा थियो\u202f।',
#    {'entities': [[38, 49, 'PLACE'],
#      [50, 57, 'PLACE'],
#      [69, 86, 'ORGANIZATION'],
#      [100, 136, 'PLACE'],
#      [177, 187, 'PLACE']]}],
#   ['पाइलट शाक्यको अवस्था स्थिर, आईसीयूबाट बिहीबार साँझ क्याबिनमा स्थानान्तरण',
#    {'entities': [[0, 5, 'POST'], [6, 13, 'PERSON'], [51, 60, 'PLACE']]}],
#   ['काठमाडौँ — त्रिभुवन अन्तर्राष्ट्रिय विमानस्थल परिसरमा बुधबार बिहान दुर्घटनाग्रस्त सौर्य एयरलाइन्सको जहाजका चालक मनीषरत्न शाक्यले धावनमार्गबाट केही माथि उडेपछि आफूले जहाज नियन्त्रण नै गर्न नसकेको बताएका छन् ।',
#    {'entities': [[0, 8, 'PLACE'],
#      [11, 45, 'PLACE'],
#      [82, 99, 'ORGANIZATION'],
#      [112, 128, 'PERSON']]}],
#   ['काठमाडौं मेडिकल कलेज तथा शिक्षण अस्पतालमा उपचाररत शाक्यले अस्पतालका निर्देशक प्रा.डा. मीना थापासँग दुर्घटनाबारे सामान्य कुराकानी गरेका हुन् । ‘करिब १०० फिट जति माथि पुगेपछि मैले कन्ट्रोल नै गर्न सकिनँ,’ क्याप्टेन शाक्यले बिहीबार थापासँग भनेका छन्, ‘त्यसपछि धेरै याद छैन । केहीले थिचिएको जस्तो लाग्छ । पछि मलाई निकालेर यता ल्याइएछ ।’',
#    {'entities': [[0, 8, 'PLACE'],
#      [9, 41, 'ORGANIZATION'],
#      [68, 76, 'POST'],
#      [77, 85, 'POST'],
#      [86, 98, 'PERSON'],
#      [203, 212, 'POST'],
#      [213, 220, 'PERSON'],
#      [229, 236, 'PERSON']]}],
#   ['प्रा.डा. थापाका अनुसार बिहीबार आईसीयूमा नजिकका आफन्तलाई मात्रै भेट्ने अनुमति दिइएको थियो । क्याप्टेन शाक्यलाई दुर्घटना छानबिन आयोगका तर्फबाट एक चिकित्सकले पनि भेटेको जानकारी आफूले पाएको उनले बताइन् । ‘क्याप्टेन शाक्यलाई मानसिक तनाव बढ्छ भनेरै अस्पताल प्रशासनले धेरैलाई भेटघाट गर्न रोक लगाएको छ,’ प्रा.डा. थापाले भनिन् ।',
#    {'entities': [[0, 8, 'POST'],
#      [9, 15, 'PERSON'],
#      [91, 100, 'POST'],
#      [101, 109, 'PERSON'],
#      [144, 154, 'POST'],
#      [200, 210, 'POST'],
#      [211, 219, 'PERSON'],
#      [296, 304, 'POST'],
#      [305, 311, 'PERSON']]}],
#   ['दुर्घटनालगत्तै उद्धार गरेर क्याप्टेन शाक्यलाई विमानस्थलबाट नजिकै रहेको काठमाडौं मेडिकल कलेज तथा शिक्षण अस्पताल पुर्\u200dयाइएको थियो । अस्पतालको आकस्मिक कक्षमा प्राथमिक उपचारपछि उनलाई निगरानीका लागि सघन उपचार कक्ष (आईसीयू) मा राखिएको थियो । बिहीबार साँझ भने उनलाई क्याबिनमा सारिएको छ । क्याप्टेन शाक्यको अवस्था खतरामुक्त र सुधारोन्मुख रहेको अस्पतालले बताएको छ । अस्पताल निर्देशक प्रा.डा. थापाका अनुसार शाक्यलाई न्युरो र हाडजोर्नी विशेषज्ञ चिकित्सकहरूको निगरानीमा राखिएको छ । ‘उहाँको अनुहार, आँखा, नाक र टाउकामा चोट लागेको छ, ढाडको एउटा हड्डीका साथै देब्रेपट्टिका तीनवटा करङ भाँचिएका छन्,’ उनले भनिन्, ‘ढाडको हड्डीको शल्यक्रिया गर्ने वा नगर्ने र गर्ने भए कहिले भन्ने निर्णय भइसकेको छैन ।’',
#    {'entities': [[27, 36, 'POST'],
#      [37, 45, 'PERSON'],
#      [71, 91, 'ORGANIZATION'],
#      [96, 110, 'ORGANIZATION'],
#      [281, 290, 'POST'],
#      [365, 373, 'POST'],
#      [374, 382, 'POST'],
#      [383, 389, 'PLACE'],
#      [397, 405, 'PLACE'],
#      [406, 433, 'POST'],
#      [434, 447, 'POST']]}],
#   ['विमानस्थलको कोटेश्वरतर्फ रनवे ०२ बाट उडेको सौर्यको विमान बिहान ११ बजेर ११ मिनेटमा दुर्घटनामा परेको थियो । विमान दुर्घटनामा १८ जनाको ज्यान गएको थियो । दुर्घटना भएको २३ मिनेटपछि शाक्यलाई भने उद्धार गरेर अस्पताल पुर्\u200dयाइएको थियो । उद्धारमा खटिएका प्रहरीका अनुसार दुर्घटनास्थलबाट उद्धार गर्दा क्याप्टेन शाक्य बोल्न सक्ने अवस्थामै थिए । उनले ‘म ठीक छु, अरूलाई हेर्नू’ भनिरहेका थिए ।',
#    {'entities': [[0, 11, 'PLACE'],
#      [12, 24, 'PLACE'],
#      [176, 184, 'PERSON'],
#      [244, 252, 'POST'],
#      [289, 298, 'POST'],
#      [299, 304, 'PERSON']]}]]}

# %%
data['classes']
# Out:
# ['PERSON', 'PLACE', 'ORGANIZATION', 'POST']

# %%
data['annotations'][0]
# Out:
# ['संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डेले विमान दुर्घटनाबारे सरकार गम्भीर रहेको बताएका छन् । गम्भीर रूपमा मन्त्रालय अध्ययनमा लागेको र चाँडै कारबाही लगायतका निर्णय लिइने उनले संसदीय समितिलाई जानकारी दिएका छन् । ',
#  {'entities': [[28, 41, 'POST'],
#    [42, 56, 'PERSON'],
#    [189, 204, 'ORGANIZATION']]}]

# %%
data['annotations'][0][1]
# Out:
# {'entities': [[28, 41, 'POST'],
#   [42, 56, 'PERSON'],
#   [189, 204, 'ORGANIZATION']]}

# %%
print(data['annotations'][0][1]['entities'])

for entity in data['annotations'][0][1]['entities']:
    print(entity)
# Out:
# [[28, 41, 'POST'], [42, 56, 'PERSON'], [189, 204, 'ORGANIZATION']]
# [28, 41, 'POST']
# [42, 56, 'PERSON']
# [189, 204, 'ORGANIZATION']

# %% [markdown]
# Exploring what those numbers are

# %%
full_text = data['annotations'][0][0]
full_text
# Out:
# 'संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डेले विमान दुर्घटनाबारे सरकार गम्भीर रहेको बताएका छन् । गम्भीर रूपमा मन्त्रालय अध्ययनमा लागेको र चाँडै कारबाही लगायतका निर्णय लिइने उनले संसदीय समितिलाई जानकारी दिएका छन् । '

# %%
print(full_text[28:41])
print(full_text[42: 56])
# Out:
# उड्डयनमन्त्री
# बद्री पाण्डेले

# %% [markdown]
# ### Translate and Load data

# %%
import json

# %%
# load data
with open('spacy-ner/train-ner-annotations.json', 'r') as f:
    data = json.load(f)
data
# Out:
# {'classes': ['PERSON', 'PLACE', 'ORGANIZATION', 'POST'],
#  'annotations': [['संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डेले विमान दुर्घटनाबारे सरकार गम्भीर रहेको बताएका छन् । गम्भीर रूपमा मन्त्रालय अध्ययनमा लागेको र चाँडै कारबाही लगायतका निर्णय लिइने उनले संसदीय समितिलाई जानकारी दिएका छन् । ',
#    {'entities': [[28, 41, 'POST'],
#      [42, 56, 'PERSON'],
#      [189, 204, 'ORGANIZATION']]}],
#   ['प्रतिनिधिसभा अन्तर्गतको अन्तर्राष्ट्रिय सम्बन्ध र पर्यटन समितिको बिहीबारको बैठकमा सांसदहरूले विमान र हेलिकप्टर दुर्घनाबारे सोधेका प्रश्नको जवाफ दिने क्रममा मन्त्री पाण्डेले कानुन र संवैधानिक रूपमा परिपक्व निर्णय लिन लागिएको बताएका हुन् ।',
#    {'entities': [[0, 23, 'ORGANIZATION'],
#      [24, 64, 'ORGANIZATION'],
#      [156, 163, 'POST'],
#      [164, 172, 'PERSON']]}],
#   ["'मातहतका निकायलाई कारबाही गर्ने सम्बन्धमा घोत्लिएका छौं । खासगरी सौर्य एयरलाइन्सको विमान दुर्घटनापछि हामी घोत्लिएका छौं,' मन्त्री पाण्डेले भने, 'म के चाहन्न भने मन्त्रीको पहलकदमीमा कुनै निर्णय होस् र अर्को कुनै बाटोबाट पुनर्स्थापति होस् र मन्त्री त्यहीँ बसिरहोस्, मेरो निर्णयमा चुनौती जुनसुकै निकायबाट आओस् त्यो निकायबाट चुनौती आइसकेपछि अथवा बदर भइसकेपछि त्यो मन्त्रीले त्यही बसिरहने नैतिक अधिकार हुन्न । मन्त्रीले गरेको निर्णय संवैधानिक कानुनी हिसाबले सम्परीक्षण भएको हुनुपर्छ । सर्वस्वीकृत हुनुपर्छ । होइन भने मन्त्रीले त्यहाँ बस्ने नैतिक अधिकार राख्दैन त्यहीअनुसार छलफल गरिरहेका छौं । चाडै सभापतिमार्फत यो समितिले पनि थाहा पाउनेछ र मुलुकले थाहा पाउनेछ भन्ने विश्वास दिलाउन चाहन्छु ।'",
#    {'entities': [[65, 82, 'ORGANIZATION'],
#      [130, 138, 'PERSON'],
#      [405, 414, 'POST'],
#      [512, 521, 'POST'],
#      [593, 605, 'POST']]}],
#   ["समितिमा सांसदहरूले जिम्मेवार अधिकारीहरूलाई निलम्बन गरेर मात्रै छानबिनको माग गरेका थिए । नैतिकताका आधारमा पनि पदमा राख्न नहुने उनीहरूको भनाइ थियो । यस विषयमा मन्त्री पाण्डेले भने, 'केही विषयहरू निलम्बन लगायतका विषयहरू आएका छन् । नैतिकताको प्रश्न व्यक्तिमा निहित हुन्छ अरु कसैले लाद्ने विषय होइन । मेरो नैतिकताको प्रश्न मैमाथि निहित हुन्छ । अरु कसैको नैतिकताको प्रश्न उसैमा निहीत हुन्छ । लादेर नैतिकता लादिँदैन । कानुनी प्रक्रियासम्मत बाटोबाट जानका लागि अप्ठ्यारा र जटिलता के हुन् खोतलिरहेका छौं ।'",
#    {'entities': [[63, 81, 'ORGANIZATION'],
#      [120, 125, 'POST'],
#      [126, 139, 'PERSON'],
#      [238, 254, 'POST'],
#      [359, 371, 'POST'],
#      [400, 417, 'POST']]}],
#   ['आफूमाथि नैतिकताको प्रश्न उठेमा एक क्षण पनि मन्त्री पदमा नबस्ने पाण्डेको भनाइ थियो ।',
#    {'entities': [[43, 50, 'POST'], [63, 71, 'PERSON']]}],
#   ['संस्कृति, पर्यटन र नागरिक उड्डयन क्षेत्रमा तमाम विकृति रहेको बताउँदै मन्त्री पाण्डेले तिनको समाधानमा आफू लागेको बताए ।',
#    {'entities': [[0, 8, 'ORGANIZATION'],
#      [69, 76, 'POST'],
#      [77, 85, 'PERSON']]}],
#   ['उक्त हेलिकप्टर क्याप्टेन अरुण मल्लले उडाएका थिए भने ४ चिनियाँ पर्यटक स्याफ्रुबेंसी लगिँदै थियो । एयर डाइनेस्टीको ४ चिनियाँ पर्यटक छाडेर फेरि विदेशी नागरिक ल्याउने तालिका बनाएको थियो ।',
#    {'entities': [[15, 24, 'POST'],
#      [25, 36, 'PERSON'],
#      [69, 82, 'PLACE'],
#      [97, 112, 'ORGANIZATION']]}],
#   ['बुधबार दिउँसो दुर्घटना भएको एयर डाइनेस्टीको हेलिकप्टरका क्याप्टेन र ४ चिनियाँ पर्यटकको मृत्यु भएको छ । मृत्यु हुनेमा क्याप्टेन अरुण मल्ल र चिनियाँ नागरिकहरू जुताड ताङ, ताइ ली, जेमिङ जी र यीयाड वु रहेका छन् । मृत्यु हुनेमा ४ पुरुष र १ महिला छन् ।',
#    {'entities': [[28, 43, 'ORGANIZATION'],
#      [56, 77, 'PERSON'],
#      [127, 136, 'PERSON'],
#      [157, 166, 'PERSON'],
#      [168, 174, 'PERSON'],
#      [176, 184, 'PERSON'],
#      [187, 195, 'PERSON']]}],
#   ['प्रत्यक्षदर्शीका अनुसार हेलिकप्टर रुखमा ठोक्किएर आगो लाग्दै झरेको थियो ।',
#    {'entities': [[0, 16, 'PERSON']]}],
#   ['दुर्घटनाको कारणबारे पत्ता लागेको छैन । उक्त उडान हुँदा भिजिविलिटी ५ किलोमिटर तथा सामान्य रहेको थियो ।',
#    {'entities': []}],
#   ['घटनाको खबर आउनेवित्तिसकै खोजीमा अर्को हेलिकोप्टर पठाइएको थियो । त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलबाट प्रभु एयरको हेलिकोप्टार परिचालन गरिएको थियो ।',
#    {'entities': [[64, 101, 'PLACE'], [102, 113, 'ORGANIZATION']]}],
#   ["गुर्जेभन्ज्याङको अस्थायी प्रहरी पोस्टका हवल्दार राजन खत्रीका अनुसार ४ पुरुष १ महिलाको शव फेला परेको छ । उनले भने, 'हेलिकप्टर खोल्सामा परेको छ । शव निकाल्न गाह्रो भइरहेको छ ।'",
#    {'entities': [[0, 16, 'PLACE'], [40, 47, 'POST'], [48, 60, 'PERSON']]}],
#   ['काठमाडौँ — बुधबार दिउँसो दुर्घटना भएको एयर डाइनेस्टीको हेलिकप्टरमा सवार पाँचै जनाको ज्यान गएको छ । बुधबार १ बजेर १४ मिनेटमा त्रिभुवन विमानस्थलबाट ४ चिनियाँ यात्रु लिएर उडेको उक्त हेलिकप्टर नुवाकोट शिवपुरी गाउँपालिका-७ सूर्यचौर डाँडा र गुर्जेभन्ज्याङको बीचमा दुर्घटना हुँदा हेलिकप्टरमा सवार पाँचै जनाको ज्यान गएको हो । ',
#    {'entities': [[39, 54, 'ORGANIZATION'],
#      [124, 145, 'PLACE'],
#      [189, 196, 'PLACE'],
#      [197, 204, 'PLACE'],
#      [218, 232, 'PLACE'],
#      [235, 251, 'PLACE']]}],
#   ['काठमाडौँ — एयर डाइनेस्टीको ९ एन-एजेडी रजिस्ट्रेसन रहेको हेलिकप्टर त्रिभुवन विमानस्थलबाट उडेको तीन मिनेटपछि नै काठमाडौं विमानस्थलमा रहेको टावरसँग सम्पर्क विच्छेद भएको थियो ।',
#    {'entities': [[11, 26, 'ORGANIZATION'],
#      [66, 87, 'PLACE'],
#      [110, 130, 'PLACE']]}],
#   ['नेपाल नागरिक उडड्यन प्राधिकरण, खोज तथा उद्धार समन्वय केन्द्रले बुधबार जारी गरेको विज्ञप्तिअनुसार सो हेलिकप्टर उडान गरेको ३ मिनेट पछि काठमाडौं टावरसँग सम्पर्क विच्छेद भई नुवाकोटको शिवपुरी गाउँपालिका-७ सूर्याचौरमा दुर्घटनामा परेको हो । दुर्घटनामा चार जना यात्रुसहित क्याप्टेनको मृत्यु भएको छ । ',
#    {'entities': [[0, 29, 'ORGANIZATION'],
#      [31, 62, 'ORGANIZATION'],
#      [169, 178, 'PLACE'],
#      [179, 186, 'PLACE'],
#      [200, 211, 'PLACE']]}],
#   ['काठमाडौँ — प्रधानमन्त्री केपी शर्मा ओलीले नुवाकोटमा बुधबार दिउँसो एयर डाइनेष्टीको हेलिकप्टर दुर्घटना भएकोप्रति दुःख व्यक्त गरेका छन् । ',
#    {'entities': [[11, 24, 'POST'],
#      [25, 41, 'PERSON'],
#      [42, 51, 'PLACE'],
#      [66, 81, 'ORGANIZATION']]}],
#   ['सिंहदरबारस्थित उपत्यका मेयर्स फोरमका पदाधिकारीसँग पूर्व निर्धारित भेटघाटमा रहेका प्रधानमन्त्री ओलीले दुर्घटनाको खबर थाहा पाएपछि भारी मनका साथ नगरप्रमुखहरुसँग प्रस्तुत हुँदै भेटघाटलाई संक्षिप्त बनाएका थिए । ',
#    {'entities': [[0, 14, 'PLACE'],
#      [15, 36, 'ORGANIZATION'],
#      [81, 94, 'POST'],
#      [95, 100, 'PERSON'],
#      [142, 157, 'POST']]}],
#   ['प्रधानमन्त्री ओलीले १४ दिनपछि अर्काे हवाइ दुर्घटना हुनु दुःखद् भएको बताए । उक्त दुर्घटनाका सम्बन्धमा केही बेरपछि मन्त्रिपरिषद्को आकरिस्मक बैठक बस्ने तयारी भएको छ ।',
#    {'entities': [[0, 13, 'POST'],
#      [14, 19, 'PERSON'],
#      [113, 128, 'ORGANIZATION']]}],
#   ['दुर्घटना भएयता सौर्य एयरलाइन्सका कुनै पनि उच्च पदस्थ अधिकारीहरू सान्त्वना दिनसमेत नआएको भन्दै मृतकका आफन्तद्वारा रोष प्रकट',
#    {'entities': [[15, 32, 'ORGANIZATION'], [42, 63, 'POST']]}],
#   ['काठमाडौँ — सौर्य एयरलाइन्सको जहाज दुर्घटनामा मृत्यु भएका १८ जनाको शव पोस्टमार्टम सकिएको छ\u202f। शव पहिचान कार्य शुक्रबार बिहान सुरु गर्ने र चिनिएका शव परिवारलाई बुझाउने त्रिवि शिक्षण अस्पतालको तयारी छ\u202f। मृतकका परिवारजन भने बिमा र एयरलाइन्सले दिने क्षतिपूर्तिको टुंगो नलागेसम्म शव नबुझ्ने अडानमा छन्\u202f। ',
#    {'entities': [[11, 28, 'ORGANIZATION'], [165, 188, 'ORGANIZATION']]}],
#   ['त्रिवि शिक्षण अस्पताल महाराजगन्जका फरेन्सिक विभाग प्रमुख डा. गोपाल चौधरीका अनुसार १८ शवमध्ये एक महिला र एक बालकको शव पहिचानका लागि कुनै समस्या छैन\u202f। ‘अन्य १२ शवलाई परिवारले दिएको विवरणअनुसार पहिचान गर्न सकिन्छ जस्तो लाग्छ,’ उनले भने, ‘चार वटा शव भने आगोले डढेका कारण पहिचान गर्न कठिन हुन सक्छ\u202f।’',
#    {'entities': [[0, 34, 'ORGANIZATION'],
#      [35, 49, 'ORGANIZATION'],
#      [50, 56, 'POST'],
#      [57, 60, 'POST'],
#      [61, 74, 'PERSON']]}],
#   ['डा. चौधरीका अनुसार लुगा, बोकेका ग्याजेट, शरीरमा रहेको ट्याटु वा चोटपटकबारे परिवारले दिएको विवरणका आधारमा शव पहिचान गरिन्छ\u202f। शल्यक्रिया गरेको भए त्यसको विवरणका आधारमा चिन्न सहज हुन्छ\u202f। कसैले दाँतको उपचार गराएको भए त्यसको विवरणबाट शव चिन्न सजिलो हुन्छ\u202f। ‘मृतकको दाँत देखिने गरी हाँसेको तस्बिर भए त्यो पनि उपलब्ध गराउन आग्रह गरेका छौं,’ डा. चौधरीले भने, ‘तपाईंहरूले सबै दाँत एकै प्रकारको देखे पनि हामी फरक देख्छौं\u202f। औंठाको छापबाट पनि पहिचान गर्न सकिन्छ\u202f।’',
#    {'entities': [[0, 3, 'POST'],
#      [4, 11, 'PERSON'],
#      [334, 337, 'POST'],
#      [338, 345, 'PERSON']]}],
#   ['डीएनए म्याचिङलाई भने शव पहिचानको अन्तिम विधिका रूपमा मात्रै प्रयोग गरिन्छ\u202f। ‘डीएनए परीक्षणका लागि नमुना संकलन गर्नै पनि कठिन हुन्छ\u202f। त्यसमाथि परीक्षणको नतिजा आउन थोरैमा पनि १२ दिन लाग्छ,’ डा. चौधरीले भने, ‘सकेसम्म डीएनए परीक्षण नगरीकनै शव पहिचान गर्ने विधिलाई प्राथमिकता दिन्छौं\u202f।’',
#    {'entities': [[188, 191, 'POST'], [192, 199, 'PERSON']]}],
#   ['फरेन्सिक विज्ञ डा. चौधरीको नेतृत्वमा पाटन स्वास्थ्य विज्ञान प्रतिष्ठान तथा भक्तपुर जिल्ला अस्पतालका समेत गरी २५ भन्दा बढी डाक्टर र स्वास्थ्यकर्मी पोस्टमार्टममा खटिएका थिए\u202f। डा. चौधरीका अनुसार विमान दुर्घटनामा परेकाले पोस्टमार्टममा मृत्युको कारण खोज्नुपर्दैन तर शव आफन्तजनलाई बुझाउनयोग्य बनाउनै धेरै समय लाग्छ\u202f। ‘भोलि (शुक्रबार) ४ बजेसम्ममा पहिचान भएका शव परिवारलाई बुझाउने कोसिसमा छौं,’ डा. चौधरीले भने\u202f।',
#    {'entities': [[0, 14, 'POST'],
#      [15, 18, 'POST'],
#      [37, 70, 'ORGANIZATION'],
#      [75, 99, 'ORGANIZATION'],
#      [122, 128, 'POST'],
#      [131, 145, 'POST'],
#      [173, 176, 'POST'],
#      [177, 184, 'PERSON'],
#      [387, 390, 'POST'],
#      [391, 398, 'PERSON']]}],
#   ['विमान दुर्घटनामा ज्यान गुमाएकाहरू आफन्त एवं परिवारजनले शव हस्तान्तरण अघि नै बिमा र यथोचित क्षतिपूर्ति रकम टुंगो लगाउन संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डे र सौर्य एयरलाइन्सका एकाउन्टेबल म्यानेजर गोपाल भट्टराईसँग माग गरेका छन्\u202f। मृतकका आफन्तलाई भेट्न मन्त्री पाण्डे र एयरलाइन्सका एकाउन्टेबल म्यानेजर भट्टराई बिहीबार त्रिवि शिक्षण अस्पताल पुगेका थिए\u202f। त्यही बेला मृतकका आफन्तले क्षतिपूर्तिको टुंगो नलागेसम्म शव नबुझ्ने अडान सुनाएका हुन्\u202f।',
#    {'entities': [[146, 159, 'POST'],
#      [160, 172, 'PERSON'],
#      [175, 192, 'ORGANIZATION'],
#      [193, 212, 'POST'],
#      [213, 229, 'PERSON'],
#      [268, 275, 'POST'],
#      [276, 282, 'PERSON'],
#      [297, 316, 'POST'],
#      [317, 324, 'PERSON'],
#      [333, 354, 'ORGANIZATION']]}],
#   ['दुर्घटना भएयता सौर्य एयरलाइन्सका कुनै पनि उच्च पदस्थ अधिकारीहरू आफूहरूलाई भेट्न वा सान्त्वना दिन नआएको बताउँदै उनीहरूले रोष प्रकट गरेका थिए\u202f। ‘एयरलाइन्सकै कर्मचारीहरू दुर्घटनामा पर्दासमेत कम्पनीले एउटा समवेदना सन्देशसमेत निकालेको छैन, भेट्न आउने त परको कुरा,’ एक आफन्तले भने, ‘हामीले के आधारमा कम्पनीका प्रतिनिधि भनेर आएका मान्छेको विश्वास गर्ने\u202f?’',
#    {'entities': [[15, 32, 'ORGANIZATION'],
#      [155, 166, 'POST'],
#      [303, 312, 'POST']]}],
#   ['शिक्षण अस्पतालको फरेन्सिक विभाग रहेको भवनमा जम्मा भएका प्रायः सबै आफन्तले सौर्य एयरलाइन्सले मृतकका परिवारलाई बेवास्ता गरेको आरोप लगाइरहेका थिए\u202f। एयरलाइन्सले आफ्नो मागको उचित सम्बोधन नगरे आपराधिक घटनाका रूपमा छानबिन गर्न प्रहरीमा जाहेरी दिने तयारी पनि रहेको उनीहरूले सुनाए\u202f। छलफलका क्रममा एयरलाइन्सका प्रतिनिधि भट्टराईले दुर्घटनापछि उचित बिमाका लागि कम्पनीले कानुनी प्रतिनिधिमार्फत बिमा कम्पनीसँग छलफल सुरु गरिसकेको जानकारी दिएका थिए\u202f।',
#    {'entities': [[0, 16, 'ORGANIZATION'],
#      [17, 31, 'ORGANIZATION'],
#      [74, 91, 'ORGANIZATION'],
#      [310, 319, 'PERSON'],
#      [358, 380, 'POST']]}],
#   ['‘काममा खटिएकै अवस्थामा हाम्रा कर्मचारीहरू दुर्घटनामा परे भनेर बिमा कम्पनीसँग कुरा गर्न वकिल राखिसकेका छौं\u202f। त्यसमा हामीले जतिसक्दो धेरै बिमा प्राप्त गर्नका लागि कुरा गर्छौं,’ उनले भने, ‘अहिले नै यति रकम भनेर उद्घोष गर्दा हामी तल पर्ने अवस्था आउन सक्छ\u202f। त्यसैले यतिउति रकम नभनौं\u202f।’ उनले सबैले यथोचित क्षतिपूर्ति प्राप्तिको अवस्था सिर्जना गर्न एयरलाइन्स लागिरहेको बताए\u202f।',
#    {'entities': [[30, 41, 'POST'],
#      [57, 76, 'ORGANIZATION'],
#      [87, 91, 'POST']]}],
#   ['मृतकका आफन्तले भने निर्णय गर्न सक्ने एयरलाइन्सका उच्च अधिकारी नै छलफलमा आउनुपर्ने माग गरेका थिए\u202f। मन्त्री पाण्डेले भने शुक्रबार दिउँसोसम्म सहमतिको प्रयास गरिने आश्वासन दिएका छन्\u202f। मन्त्री पाण्डेकै पहलमा शुक्रबार दिउँसो २ बजेअघि मन्त्रालय, एयरलाइन्सका उच्च प्रतिनिधि र मृतकका आफन्तबीच अस्पतालमै छलफल हुने भएको छ\u202f।',
#    {'entities': [[49, 61, 'POST'],
#      [98, 105, 'POST'],
#      [106, 114, 'PERSON'],
#      [180, 187, 'POST'],
#      [228, 237, 'ORGANIZATION'],
#      [251, 265, 'POST']]}],
#   ['विस्तृत परीक्षण र मर्मत (सी–चेक) गर्न काठमाडौंबाट पोखराका लागि उडेको सौर्य एयरलाइन्सको विमान बुधबार त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलमा दुर्घटनामा परेको थियो\u202f। ५० सिट क्षमताको क्यानेडियन ‘बमबार्डियर जेट सीआरजे–२००’ जहाज ‘फेरि फ्लाइट’ (गैरव्यावसायिक उडान) मा थियो\u202f।',
#    {'entities': [[38, 49, 'PLACE'],
#      [50, 57, 'PLACE'],
#      [69, 86, 'ORGANIZATION'],
#      [100, 136, 'PLACE'],
#      [177, 187, 'PLACE']]}],
#   ['पाइलट शाक्यको अवस्था स्थिर, आईसीयूबाट बिहीबार साँझ क्याबिनमा स्थानान्तरण',
#    {'entities': [[0, 5, 'POST'], [6, 13, 'PERSON'], [51, 60, 'PLACE']]}],
#   ['काठमाडौँ — त्रिभुवन अन्तर्राष्ट्रिय विमानस्थल परिसरमा बुधबार बिहान दुर्घटनाग्रस्त सौर्य एयरलाइन्सको जहाजका चालक मनीषरत्न शाक्यले धावनमार्गबाट केही माथि उडेपछि आफूले जहाज नियन्त्रण नै गर्न नसकेको बताएका छन् ।',
#    {'entities': [[0, 8, 'PLACE'],
#      [11, 45, 'PLACE'],
#      [82, 99, 'ORGANIZATION'],
#      [112, 128, 'PERSON']]}],
#   ['काठमाडौं मेडिकल कलेज तथा शिक्षण अस्पतालमा उपचाररत शाक्यले अस्पतालका निर्देशक प्रा.डा. मीना थापासँग दुर्घटनाबारे सामान्य कुराकानी गरेका हुन् । ‘करिब १०० फिट जति माथि पुगेपछि मैले कन्ट्रोल नै गर्न सकिनँ,’ क्याप्टेन शाक्यले बिहीबार थापासँग भनेका छन्, ‘त्यसपछि धेरै याद छैन । केहीले थिचिएको जस्तो लाग्छ । पछि मलाई निकालेर यता ल्याइएछ ।’',
#    {'entities': [[0, 8, 'PLACE'],
#      [9, 41, 'ORGANIZATION'],
#      [68, 76, 'POST'],
#      [77, 85, 'POST'],
#      [86, 98, 'PERSON'],
#      [203, 212, 'POST'],
#      [213, 220, 'PERSON'],
#      [229, 236, 'PERSON']]}],
#   ['प्रा.डा. थापाका अनुसार बिहीबार आईसीयूमा नजिकका आफन्तलाई मात्रै भेट्ने अनुमति दिइएको थियो । क्याप्टेन शाक्यलाई दुर्घटना छानबिन आयोगका तर्फबाट एक चिकित्सकले पनि भेटेको जानकारी आफूले पाएको उनले बताइन् । ‘क्याप्टेन शाक्यलाई मानसिक तनाव बढ्छ भनेरै अस्पताल प्रशासनले धेरैलाई भेटघाट गर्न रोक लगाएको छ,’ प्रा.डा. थापाले भनिन् ।',
#    {'entities': [[0, 8, 'POST'],
#      [9, 15, 'PERSON'],
#      [91, 100, 'POST'],
#      [101, 109, 'PERSON'],
#      [144, 154, 'POST'],
#      [200, 210, 'POST'],
#      [211, 219, 'PERSON'],
#      [296, 304, 'POST'],
#      [305, 311, 'PERSON']]}],
#   ['दुर्घटनालगत्तै उद्धार गरेर क्याप्टेन शाक्यलाई विमानस्थलबाट नजिकै रहेको काठमाडौं मेडिकल कलेज तथा शिक्षण अस्पताल पुर्\u200dयाइएको थियो । अस्पतालको आकस्मिक कक्षमा प्राथमिक उपचारपछि उनलाई निगरानीका लागि सघन उपचार कक्ष (आईसीयू) मा राखिएको थियो । बिहीबार साँझ भने उनलाई क्याबिनमा सारिएको छ । क्याप्टेन शाक्यको अवस्था खतरामुक्त र सुधारोन्मुख रहेको अस्पतालले बताएको छ । अस्पताल निर्देशक प्रा.डा. थापाका अनुसार शाक्यलाई न्युरो र हाडजोर्नी विशेषज्ञ चिकित्सकहरूको निगरानीमा राखिएको छ । ‘उहाँको अनुहार, आँखा, नाक र टाउकामा चोट लागेको छ, ढाडको एउटा हड्डीका साथै देब्रेपट्टिका तीनवटा करङ भाँचिएका छन्,’ उनले भनिन्, ‘ढाडको हड्डीको शल्यक्रिया गर्ने वा नगर्ने र गर्ने भए कहिले भन्ने निर्णय भइसकेको छैन ।’',
#    {'entities': [[27, 36, 'POST'],
#      [37, 45, 'PERSON'],
#      [71, 91, 'ORGANIZATION'],
#      [96, 110, 'ORGANIZATION'],
#      [281, 290, 'POST'],
#      [365, 373, 'POST'],
#      [374, 382, 'POST'],
#      [383, 389, 'PLACE'],
#      [397, 405, 'PLACE'],
#      [406, 433, 'POST'],
#      [434, 447, 'POST']]}],
#   ['विमानस्थलको कोटेश्वरतर्फ रनवे ०२ बाट उडेको सौर्यको विमान बिहान ११ बजेर ११ मिनेटमा दुर्घटनामा परेको थियो । विमान दुर्घटनामा १८ जनाको ज्यान गएको थियो । दुर्घटना भएको २३ मिनेटपछि शाक्यलाई भने उद्धार गरेर अस्पताल पुर्\u200dयाइएको थियो । उद्धारमा खटिएका प्रहरीका अनुसार दुर्घटनास्थलबाट उद्धार गर्दा क्याप्टेन शाक्य बोल्न सक्ने अवस्थामै थिए । उनले ‘म ठीक छु, अरूलाई हेर्नू’ भनिरहेका थिए ।',
#    {'entities': [[0, 11, 'PLACE'],
#      [12, 24, 'PLACE'],
#      [176, 184, 'PERSON'],
#      [244, 252, 'POST'],
#      [289, 298, 'POST'],
#      [299, 304, 'PERSON']]}]]}

# %%
training_dataset = [ ]

# prepare the data from the json file
for annotation in data['annotations']:
    # check for the data
    # print(annotation[0])
    # print(annotation[1])
    if annotation is None: continue
    temp_data = { }
    temp_data['text'] = annotation[0]
    temp_data['entities'] = [ ]

    for entity in annotation[1]['entities']:
        # print(entity)
        start, end, label = entity
        # print(start, end, label)
        temp_data['entities'].append((start, end, label))
    training_dataset.append(temp_data)

# %%
# dataset
training_dataset
# Out:
# [{'text': 'संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डेले विमान दुर्घटनाबारे सरकार गम्भीर रहेको बताएका छन् । गम्भीर रूपमा मन्त्रालय अध्ययनमा लागेको र चाँडै कारबाही लगायतका निर्णय लिइने उनले संसदीय समितिलाई जानकारी दिएका छन् । ',
#   'entities': [(28, 41, 'POST'),
#    (42, 56, 'PERSON'),
#    (189, 204, 'ORGANIZATION')]},
#  {'text': 'प्रतिनिधिसभा अन्तर्गतको अन्तर्राष्ट्रिय सम्बन्ध र पर्यटन समितिको बिहीबारको बैठकमा सांसदहरूले विमान र हेलिकप्टर दुर्घनाबारे सोधेका प्रश्नको जवाफ दिने क्रममा मन्त्री पाण्डेले कानुन र संवैधानिक रूपमा परिपक्व निर्णय लिन लागिएको बताएका हुन् ।',
#   'entities': [(0, 23, 'ORGANIZATION'),
#    (24, 64, 'ORGANIZATION'),
#    (156, 163, 'POST'),
#    (164, 172, 'PERSON')]},
#  {'text': "'मातहतका निकायलाई कारबाही गर्ने सम्बन्धमा घोत्लिएका छौं । खासगरी सौर्य एयरलाइन्सको विमान दुर्घटनापछि हामी घोत्लिएका छौं,' मन्त्री पाण्डेले भने, 'म के चाहन्न भने मन्त्रीको पहलकदमीमा कुनै निर्णय होस् र अर्को कुनै बाटोबाट पुनर्स्थापति होस् र मन्त्री त्यहीँ बसिरहोस्, मेरो निर्णयमा चुनौती जुनसुकै निकायबाट आओस् त्यो निकायबाट चुनौती आइसकेपछि अथवा बदर भइसकेपछि त्यो मन्त्रीले त्यही बसिरहने नैतिक अधिकार हुन्न । मन्त्रीले गरेको निर्णय संवैधानिक कानुनी हिसाबले सम्परीक्षण भएको हुनुपर्छ । सर्वस्वीकृत हुनुपर्छ । होइन भने मन्त्रीले त्यहाँ बस्ने नैतिक अधिकार राख्दैन त्यहीअनुसार छलफल गरिरहेका छौं । चाडै सभापतिमार्फत यो समितिले पनि थाहा पाउनेछ र मुलुकले थाहा पाउनेछ भन्ने विश्वास दिलाउन चाहन्छु ।'",
#   'entities': [(65, 82, 'ORGANIZATION'),
#    (130, 138, 'PERSON'),
#    (405, 414, 'POST'),
#    (512, 521, 'POST'),
#    (593, 605, 'POST')]},
#  {'text': "समितिमा सांसदहरूले जिम्मेवार अधिकारीहरूलाई निलम्बन गरेर मात्रै छानबिनको माग गरेका थिए । नैतिकताका आधारमा पनि पदमा राख्न नहुने उनीहरूको भनाइ थियो । यस विषयमा मन्त्री पाण्डेले भने, 'केही विषयहरू निलम्बन लगायतका विषयहरू आएका छन् । नैतिकताको प्रश्न व्यक्तिमा निहित हुन्छ अरु कसैले लाद्ने विषय होइन । मेरो नैतिकताको प्रश्न मैमाथि निहित हुन्छ । अरु कसैको नैतिकताको प्रश्न उसैमा निहीत हुन्छ । लादेर नैतिकता लादिँदैन । कानुनी प्रक्रियासम्मत बाटोबाट जानका लागि अप्ठ्यारा र जटिलता के हुन् खोतलिरहेका छौं ।'",
#   'entities': [(63, 81, 'ORGANIZATION'),
#    (120, 125, 'POST'),
#    (126, 139, 'PERSON'),
#    (238, 254, 'POST'),
#    (359, 371, 'POST'),
#    (400, 417, 'POST')]},
#  {'text': 'आफूमाथि नैतिकताको प्रश्न उठेमा एक क्षण पनि मन्त्री पदमा नबस्ने पाण्डेको भनाइ थियो ।',
#   'entities': [(43, 50, 'POST'), (63, 71, 'PERSON')]},
#  {'text': 'संस्कृति, पर्यटन र नागरिक उड्डयन क्षेत्रमा तमाम विकृति रहेको बताउँदै मन्त्री पाण्डेले तिनको समाधानमा आफू लागेको बताए ।',
#   'entities': [(0, 8, 'ORGANIZATION'), (69, 76, 'POST'), (77, 85, 'PERSON')]},
#  {'text': 'उक्त हेलिकप्टर क्याप्टेन अरुण मल्लले उडाएका थिए भने ४ चिनियाँ पर्यटक स्याफ्रुबेंसी लगिँदै थियो । एयर डाइनेस्टीको ४ चिनियाँ पर्यटक छाडेर फेरि विदेशी नागरिक ल्याउने तालिका बनाएको थियो ।',
#   'entities': [(15, 24, 'POST'),
#    (25, 36, 'PERSON'),
#    (69, 82, 'PLACE'),
#    (97, 112, 'ORGANIZATION')]},
#  {'text': 'बुधबार दिउँसो दुर्घटना भएको एयर डाइनेस्टीको हेलिकप्टरका क्याप्टेन र ४ चिनियाँ पर्यटकको मृत्यु भएको छ । मृत्यु हुनेमा क्याप्टेन अरुण मल्ल र चिनियाँ नागरिकहरू जुताड ताङ, ताइ ली, जेमिङ जी र यीयाड वु रहेका छन् । मृत्यु हुनेमा ४ पुरुष र १ महिला छन् ।',
#   'entities': [(28, 43, 'ORGANIZATION'),
#    (56, 77, 'PERSON'),
#    (127, 136, 'PERSON'),
#    (157, 166, 'PERSON'),
#    (168, 174, 'PERSON'),
#    (176, 184, 'PERSON'),
#    (187, 195, 'PERSON')]},
#  {'text': 'प्रत्यक्षदर्शीका अनुसार हेलिकप्टर रुखमा ठोक्किएर आगो लाग्दै झरेको थियो ।',
#   'entities': [(0, 16, 'PERSON')]},
#  {'text': 'दुर्घटनाको कारणबारे पत्ता लागेको छैन । उक्त उडान हुँदा भिजिविलिटी ५ किलोमिटर तथा सामान्य रहेको थियो ।',
#   'entities': []},
#  {'text': 'घटनाको खबर आउनेवित्तिसकै खोजीमा अर्को हेलिकोप्टर पठाइएको थियो । त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलबाट प्रभु एयरको हेलिकोप्टार परिचालन गरिएको थियो ।',
#   'entities': [(64, 101, 'PLACE'), (102, 113, 'ORGANIZATION')]},
#  {'text': "गुर्जेभन्ज्याङको अस्थायी प्रहरी पोस्टका हवल्दार राजन खत्रीका अनुसार ४ पुरुष १ महिलाको शव फेला परेको छ । उनले भने, 'हेलिकप्टर खोल्सामा परेको छ । शव निकाल्न गाह्रो भइरहेको छ ।'",
#   'entities': [(0, 16, 'PLACE'), (40, 47, 'POST'), (48, 60, 'PERSON')]},
#  {'text': 'काठमाडौँ — बुधबार दिउँसो दुर्घटना भएको एयर डाइनेस्टीको हेलिकप्टरमा सवार पाँचै जनाको ज्यान गएको छ । बुधबार १ बजेर १४ मिनेटमा त्रिभुवन विमानस्थलबाट ४ चिनियाँ यात्रु लिएर उडेको उक्त हेलिकप्टर नुवाकोट शिवपुरी गाउँपालिका-७ सूर्यचौर डाँडा र गुर्जेभन्ज्याङको बीचमा दुर्घटना हुँदा हेलिकप्टरमा सवार पाँचै जनाको ज्यान गएको हो । ',
#   'entities': [(39, 54, 'ORGANIZATION'),
#    (124, 145, 'PLACE'),
#    (189, 196, 'PLACE'),
#    (197, 204, 'PLACE'),
#    (218, 232, 'PLACE'),
#    (235, 251, 'PLACE')]},
#  {'text': 'काठमाडौँ — एयर डाइनेस्टीको ९ एन-एजेडी रजिस्ट्रेसन रहेको हेलिकप्टर त्रिभुवन विमानस्थलबाट उडेको तीन मिनेटपछि नै काठमाडौं विमानस्थलमा रहेको टावरसँग सम्पर्क विच्छेद भएको थियो ।',
#   'entities': [(11, 26, 'ORGANIZATION'),
#    (66, 87, 'PLACE'),
#    (110, 130, 'PLACE')]},
#  {'text': 'नेपाल नागरिक उडड्यन प्राधिकरण, खोज तथा उद्धार समन्वय केन्द्रले बुधबार जारी गरेको विज्ञप्तिअनुसार सो हेलिकप्टर उडान गरेको ३ मिनेट पछि काठमाडौं टावरसँग सम्पर्क विच्छेद भई नुवाकोटको शिवपुरी गाउँपालिका-७ सूर्याचौरमा दुर्घटनामा परेको हो । दुर्घटनामा चार जना यात्रुसहित क्याप्टेनको मृत्यु भएको छ । ',
#   'entities': [(0, 29, 'ORGANIZATION'),
#    (31, 62, 'ORGANIZATION'),
#    (169, 178, 'PLACE'),
#    (179, 186, 'PLACE'),
#    (200, 211, 'PLACE')]},
#  {'text': 'काठमाडौँ — प्रधानमन्त्री केपी शर्मा ओलीले नुवाकोटमा बुधबार दिउँसो एयर डाइनेष्टीको हेलिकप्टर दुर्घटना भएकोप्रति दुःख व्यक्त गरेका छन् । ',
#   'entities': [(11, 24, 'POST'),
#    (25, 41, 'PERSON'),
#    (42, 51, 'PLACE'),
#    (66, 81, 'ORGANIZATION')]},
#  {'text': 'सिंहदरबारस्थित उपत्यका मेयर्स फोरमका पदाधिकारीसँग पूर्व निर्धारित भेटघाटमा रहेका प्रधानमन्त्री ओलीले दुर्घटनाको खबर थाहा पाएपछि भारी मनका साथ नगरप्रमुखहरुसँग प्रस्तुत हुँदै भेटघाटलाई संक्षिप्त बनाएका थिए । ',
#   'entities': [(0, 14, 'PLACE'),
#    (15, 36, 'ORGANIZATION'),
#    (81, 94, 'POST'),
#    (95, 100, 'PERSON'),
#    (142, 157, 'POST')]},
#  {'text': 'प्रधानमन्त्री ओलीले १४ दिनपछि अर्काे हवाइ दुर्घटना हुनु दुःखद् भएको बताए । उक्त दुर्घटनाका सम्बन्धमा केही बेरपछि मन्त्रिपरिषद्को आकरिस्मक बैठक बस्ने तयारी भएको छ ।',
#   'entities': [(0, 13, 'POST'),
#    (14, 19, 'PERSON'),
#    (113, 128, 'ORGANIZATION')]},
#  {'text': 'दुर्घटना भएयता सौर्य एयरलाइन्सका कुनै पनि उच्च पदस्थ अधिकारीहरू सान्त्वना दिनसमेत नआएको भन्दै मृतकका आफन्तद्वारा रोष प्रकट',
#   'entities': [(15, 32, 'ORGANIZATION'), (42, 63, 'POST')]},
#  {'text': 'काठमाडौँ — सौर्य एयरलाइन्सको जहाज दुर्घटनामा मृत्यु भएका १८ जनाको शव पोस्टमार्टम सकिएको छ\u202f। शव पहिचान कार्य शुक्रबार बिहान सुरु गर्ने र चिनिएका शव परिवारलाई बुझाउने त्रिवि शिक्षण अस्पतालको तयारी छ\u202f। मृतकका परिवारजन भने बिमा र एयरलाइन्सले दिने क्षतिपूर्तिको टुंगो नलागेसम्म शव नबुझ्ने अडानमा छन्\u202f। ',
#   'entities': [(11, 28, 'ORGANIZATION'), (165, 188, 'ORGANIZATION')]},
#  {'text': 'त्रिवि शिक्षण अस्पताल महाराजगन्जका फरेन्सिक विभाग प्रमुख डा. गोपाल चौधरीका अनुसार १८ शवमध्ये एक महिला र एक बालकको शव पहिचानका लागि कुनै समस्या छैन\u202f। ‘अन्य १२ शवलाई परिवारले दिएको विवरणअनुसार पहिचान गर्न सकिन्छ जस्तो लाग्छ,’ उनले भने, ‘चार वटा शव भने आगोले डढेका कारण पहिचान गर्न कठिन हुन सक्छ\u202f।’',
#   'entities': [(0, 34, 'ORGANIZATION'),
#    (35, 49, 'ORGANIZATION'),
#    (50, 56, 'POST'),
#    (57, 60, 'POST'),
#    (61, 74, 'PERSON')]},
#  {'text': 'डा. चौधरीका अनुसार लुगा, बोकेका ग्याजेट, शरीरमा रहेको ट्याटु वा चोटपटकबारे परिवारले दिएको विवरणका आधारमा शव पहिचान गरिन्छ\u202f। शल्यक्रिया गरेको भए त्यसको विवरणका आधारमा चिन्न सहज हुन्छ\u202f। कसैले दाँतको उपचार गराएको भए त्यसको विवरणबाट शव चिन्न सजिलो हुन्छ\u202f। ‘मृतकको दाँत देखिने गरी हाँसेको तस्बिर भए त्यो पनि उपलब्ध गराउन आग्रह गरेका छौं,’ डा. चौधरीले भने, ‘तपाईंहरूले सबै दाँत एकै प्रकारको देखे पनि हामी फरक देख्छौं\u202f। औंठाको छापबाट पनि पहिचान गर्न सकिन्छ\u202f।’',
#   'entities': [(0, 3, 'POST'),
#    (4, 11, 'PERSON'),
#    (334, 337, 'POST'),
#    (338, 345, 'PERSON')]},
#  {'text': 'डीएनए म्याचिङलाई भने शव पहिचानको अन्तिम विधिका रूपमा मात्रै प्रयोग गरिन्छ\u202f। ‘डीएनए परीक्षणका लागि नमुना संकलन गर्नै पनि कठिन हुन्छ\u202f। त्यसमाथि परीक्षणको नतिजा आउन थोरैमा पनि १२ दिन लाग्छ,’ डा. चौधरीले भने, ‘सकेसम्म डीएनए परीक्षण नगरीकनै शव पहिचान गर्ने विधिलाई प्राथमिकता दिन्छौं\u202f।’',
#   'entities': [(188, 191, 'POST'), (192, 199, 'PERSON')]},
#  {'text': 'फरेन्सिक विज्ञ डा. चौधरीको नेतृत्वमा पाटन स्वास्थ्य विज्ञान प्रतिष्ठान तथा भक्तपुर जिल्ला अस्पतालका समेत गरी २५ भन्दा बढी डाक्टर र स्वास्थ्यकर्मी पोस्टमार्टममा खटिएका थिए\u202f। डा. चौधरीका अनुसार विमान दुर्घटनामा परेकाले पोस्टमार्टममा मृत्युको कारण खोज्नुपर्दैन तर शव आफन्तजनलाई बुझाउनयोग्य बनाउनै धेरै समय लाग्छ\u202f। ‘भोलि (शुक्रबार) ४ बजेसम्ममा पहिचान भएका शव परिवारलाई बुझाउने कोसिसमा छौं,’ डा. चौधरीले भने\u202f।',
#   'entities': [(0, 14, 'POST'),
#    (15, 18, 'POST'),
#    (37, 70, 'ORGANIZATION'),
#    (75, 99, 'ORGANIZATION'),
#    (122, 128, 'POST'),
#    (131, 145, 'POST'),
#    (173, 176, 'POST'),
#    (177, 184, 'PERSON'),
#    (387, 390, 'POST'),
#    (391, 398, 'PERSON')]},
#  {'text': 'विमान दुर्घटनामा ज्यान गुमाएकाहरू आफन्त एवं परिवारजनले शव हस्तान्तरण अघि नै बिमा र यथोचित क्षतिपूर्ति रकम टुंगो लगाउन संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डे र सौर्य एयरलाइन्सका एकाउन्टेबल म्यानेजर गोपाल भट्टराईसँग माग गरेका छन्\u202f। मृतकका आफन्तलाई भेट्न मन्त्री पाण्डे र एयरलाइन्सका एकाउन्टेबल म्यानेजर भट्टराई बिहीबार त्रिवि शिक्षण अस्पताल पुगेका थिए\u202f। त्यही बेला मृतकका आफन्तले क्षतिपूर्तिको टुंगो नलागेसम्म शव नबुझ्ने अडान सुनाएका हुन्\u202f।',
#   'entities': [(146, 159, 'POST'),
#    (160, 172, 'PERSON'),
#    (175, 192, 'ORGANIZATION'),
#    (193, 212, 'POST'),
#    (213, 229, 'PERSON'),
#    (268, 275, 'POST'),
#    (276, 282, 'PERSON'),
#    (297, 316, 'POST'),
#    (317, 324, 'PERSON'),
#    (333, 354, 'ORGANIZATION')]},
#  {'text': 'दुर्घटना भएयता सौर्य एयरलाइन्सका कुनै पनि उच्च पदस्थ अधिकारीहरू आफूहरूलाई भेट्न वा सान्त्वना दिन नआएको बताउँदै उनीहरूले रोष प्रकट गरेका थिए\u202f। ‘एयरलाइन्सकै कर्मचारीहरू दुर्घटनामा पर्दासमेत कम्पनीले एउटा समवेदना सन्देशसमेत निकालेको छैन, भेट्न आउने त परको कुरा,’ एक आफन्तले भने, ‘हामीले के आधारमा कम्पनीका प्रतिनिधि भनेर आएका मान्छेको विश्वास गर्ने\u202f?’',
#   'entities': [(15, 32, 'ORGANIZATION'),
#    (155, 166, 'POST'),
#    (303, 312, 'POST')]},
#  {'text': 'शिक्षण अस्पतालको फरेन्सिक विभाग रहेको भवनमा जम्मा भएका प्रायः सबै आफन्तले सौर्य एयरलाइन्सले मृतकका परिवारलाई बेवास्ता गरेको आरोप लगाइरहेका थिए\u202f। एयरलाइन्सले आफ्नो मागको उचित सम्बोधन नगरे आपराधिक घटनाका रूपमा छानबिन गर्न प्रहरीमा जाहेरी दिने तयारी पनि रहेको उनीहरूले सुनाए\u202f। छलफलका क्रममा एयरलाइन्सका प्रतिनिधि भट्टराईले दुर्घटनापछि उचित बिमाका लागि कम्पनीले कानुनी प्रतिनिधिमार्फत बिमा कम्पनीसँग छलफल सुरु गरिसकेको जानकारी दिएका थिए\u202f।',
#   'entities': [(0, 16, 'ORGANIZATION'),
#    (17, 31, 'ORGANIZATION'),
#    (74, 91, 'ORGANIZATION'),
#    (310, 319, 'PERSON'),
#    (358, 380, 'POST')]},
#  {'text': '‘काममा खटिएकै अवस्थामा हाम्रा कर्मचारीहरू दुर्घटनामा परे भनेर बिमा कम्पनीसँग कुरा गर्न वकिल राखिसकेका छौं\u202f। त्यसमा हामीले जतिसक्दो धेरै बिमा प्राप्त गर्नका लागि कुरा गर्छौं,’ उनले भने, ‘अहिले नै यति रकम भनेर उद्घोष गर्दा हामी तल पर्ने अवस्था आउन सक्छ\u202f। त्यसैले यतिउति रकम नभनौं\u202f।’ उनले सबैले यथोचित क्षतिपूर्ति प्राप्तिको अवस्था सिर्जना गर्न एयरलाइन्स लागिरहेको बताए\u202f।',
#   'entities': [(30, 41, 'POST'), (57, 76, 'ORGANIZATION'), (87, 91, 'POST')]},
#  {'text': 'मृतकका आफन्तले भने निर्णय गर्न सक्ने एयरलाइन्सका उच्च अधिकारी नै छलफलमा आउनुपर्ने माग गरेका थिए\u202f। मन्त्री पाण्डेले भने शुक्रबार दिउँसोसम्म सहमतिको प्रयास गरिने आश्वासन दिएका छन्\u202f। मन्त्री पाण्डेकै पहलमा शुक्रबार दिउँसो २ बजेअघि मन्त्रालय, एयरलाइन्सका उच्च प्रतिनिधि र मृतकका आफन्तबीच अस्पतालमै छलफल हुने भएको छ\u202f।',
#   'entities': [(49, 61, 'POST'),
#    (98, 105, 'POST'),
#    (106, 114, 'PERSON'),
#    (180, 187, 'POST'),
#    (228, 237, 'ORGANIZATION'),
#    (251, 265, 'POST')]},
#  {'text': 'विस्तृत परीक्षण र मर्मत (सी–चेक) गर्न काठमाडौंबाट पोखराका लागि उडेको सौर्य एयरलाइन्सको विमान बुधबार त्रिभुवन अन्तर्राष्ट्रिय विमानस्थलमा दुर्घटनामा परेको थियो\u202f। ५० सिट क्षमताको क्यानेडियन ‘बमबार्डियर जेट सीआरजे–२००’ जहाज ‘फेरि फ्लाइट’ (गैरव्यावसायिक उडान) मा थियो\u202f।',
#   'entities': [(38, 49, 'PLACE'),
#    (50, 57, 'PLACE'),
#    (69, 86, 'ORGANIZATION'),
#    (100, 136, 'PLACE'),
#    (177, 187, 'PLACE')]},
#  {'text': 'पाइलट शाक्यको अवस्था स्थिर, आईसीयूबाट बिहीबार साँझ क्याबिनमा स्थानान्तरण',
#   'entities': [(0, 5, 'POST'), (6, 13, 'PERSON'), (51, 60, 'PLACE')]},
#  {'text': 'काठमाडौँ — त्रिभुवन अन्तर्राष्ट्रिय विमानस्थल परिसरमा बुधबार बिहान दुर्घटनाग्रस्त सौर्य एयरलाइन्सको जहाजका चालक मनीषरत्न शाक्यले धावनमार्गबाट केही माथि उडेपछि आफूले जहाज नियन्त्रण नै गर्न नसकेको बताएका छन् ।',
#   'entities': [(0, 8, 'PLACE'),
#    (11, 45, 'PLACE'),
#    (82, 99, 'ORGANIZATION'),
#    (112, 128, 'PERSON')]},
#  {'text': 'काठमाडौं मेडिकल कलेज तथा शिक्षण अस्पतालमा उपचाररत शाक्यले अस्पतालका निर्देशक प्रा.डा. मीना थापासँग दुर्घटनाबारे सामान्य कुराकानी गरेका हुन् । ‘करिब १०० फिट जति माथि पुगेपछि मैले कन्ट्रोल नै गर्न सकिनँ,’ क्याप्टेन शाक्यले बिहीबार थापासँग भनेका छन्, ‘त्यसपछि धेरै याद छैन । केहीले थिचिएको जस्तो लाग्छ । पछि मलाई निकालेर यता ल्याइएछ ।’',
#   'entities': [(0, 8, 'PLACE'),
#    (9, 41, 'ORGANIZATION'),
#    (68, 76, 'POST'),
#    (77, 85, 'POST'),
#    (86, 98, 'PERSON'),
#    (203, 212, 'POST'),
#    (213, 220, 'PERSON'),
#    (229, 236, 'PERSON')]},
#  {'text': 'प्रा.डा. थापाका अनुसार बिहीबार आईसीयूमा नजिकका आफन्तलाई मात्रै भेट्ने अनुमति दिइएको थियो । क्याप्टेन शाक्यलाई दुर्घटना छानबिन आयोगका तर्फबाट एक चिकित्सकले पनि भेटेको जानकारी आफूले पाएको उनले बताइन् । ‘क्याप्टेन शाक्यलाई मानसिक तनाव बढ्छ भनेरै अस्पताल प्रशासनले धेरैलाई भेटघाट गर्न रोक लगाएको छ,’ प्रा.डा. थापाले भनिन् ।',
#   'entities': [(0, 8, 'POST'),
#    (9, 15, 'PERSON'),
#    (91, 100, 'POST'),
#    (101, 109, 'PERSON'),
#    (144, 154, 'POST'),
#    (200, 210, 'POST'),
#    (211, 219, 'PERSON'),
#    (296, 304, 'POST'),
#    (305, 311, 'PERSON')]},
#  {'text': 'दुर्घटनालगत्तै उद्धार गरेर क्याप्टेन शाक्यलाई विमानस्थलबाट नजिकै रहेको काठमाडौं मेडिकल कलेज तथा शिक्षण अस्पताल पुर्\u200dयाइएको थियो । अस्पतालको आकस्मिक कक्षमा प्राथमिक उपचारपछि उनलाई निगरानीका लागि सघन उपचार कक्ष (आईसीयू) मा राखिएको थियो । बिहीबार साँझ भने उनलाई क्याबिनमा सारिएको छ । क्याप्टेन शाक्यको अवस्था खतरामुक्त र सुधारोन्मुख रहेको अस्पतालले बताएको छ । अस्पताल निर्देशक प्रा.डा. थापाका अनुसार शाक्यलाई न्युरो र हाडजोर्नी विशेषज्ञ चिकित्सकहरूको निगरानीमा राखिएको छ । ‘उहाँको अनुहार, आँखा, नाक र टाउकामा चोट लागेको छ, ढाडको एउटा हड्डीका साथै देब्रेपट्टिका तीनवटा करङ भाँचिएका छन्,’ उनले भनिन्, ‘ढाडको हड्डीको शल्यक्रिया गर्ने वा नगर्ने र गर्ने भए कहिले भन्ने निर्णय भइसकेको छैन ।’',
#   'entities': [(27, 36, 'POST'),
#    (37, 45, 'PERSON'),
#    (71, 91, 'ORGANIZATION'),
#    (96, 110, 'ORGANIZATION'),
#    (281, 290, 'POST'),
#    (365, 373, 'POST'),
#    (374, 382, 'POST'),
#    (383, 389, 'PLACE'),
#    (397, 405, 'PLACE'),
#    (406, 433, 'POST'),
#    (434, 447, 'POST')]},
#  {'text': 'विमानस्थलको कोटेश्वरतर्फ रनवे ०२ बाट उडेको सौर्यको विमान बिहान ११ बजेर ११ मिनेटमा दुर्घटनामा परेको थियो । विमान दुर्घटनामा १८ जनाको ज्यान गएको थियो । दुर्घटना भएको २३ मिनेटपछि शाक्यलाई भने उद्धार गरेर अस्पताल पुर्\u200dयाइएको थियो । उद्धारमा खटिएका प्रहरीका अनुसार दुर्घटनास्थलबाट उद्धार गर्दा क्याप्टेन शाक्य बोल्न सक्ने अवस्थामै थिए । उनले ‘म ठीक छु, अरूलाई हेर्नू’ भनिरहेका थिए ।',
#   'entities': [(0, 11, 'PLACE'),
#    (12, 24, 'PLACE'),
#    (176, 184, 'PERSON'),
#    (244, 252, 'POST'),
#    (289, 298, 'POST'),
#    (299, 304, 'PERSON')]}]

# %%
training_dataset[0]['text']
# Out:
# 'संस्कृति, पर्यटन तथा नागरिक उड्डयनमन्त्री बद्री पाण्डेले विमान दुर्घटनाबारे सरकार गम्भीर रहेको बताएका छन् । गम्भीर रूपमा मन्त्रालय अध्ययनमा लागेको र चाँडै कारबाही लगायतका निर्णय लिइने उनले संसदीय समितिलाई जानकारी दिएका छन् । '

# %%
training_dataset[0]['entities']
# Out:
# [(28, 41, 'POST'), (42, 56, 'PERSON'), (189, 204, 'ORGANIZATION')]

# %% [markdown]
# ### Spacy compatible dataset
#
# - **Conversion to spaCy Format:** It transforms annotated data into a format compatible with spaCy v3, creating Doc objects with character spans linked to entities.
#
# - **Entity Alignment:** Prevents entity overlaps or conflicts within documents, avoiding training issues.

# %%
import spacy
from spacy.tokens import DocBin
from spacy.util import filter_spans
from tqdm import tqdm

# %%
def build_docbin(dataset_):
    nlp = spacy.blank("ne") # load a new spacy model
    doc_bin = DocBin()
    # iterate over data
    for training_data  in tqdm(dataset_):
        text = training_data['text']
        labels = training_data['entities']
        doc = nlp.make_doc(text) 
        ents = []
        for start, end, label in labels:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
        filtered_ents = filter_spans(ents)
        doc.ents = filtered_ents 
        doc_bin.add(doc)
    return doc_bin

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(training_dataset, test_size=0.2)

# %%
doc_bin_train = build_docbin(train)
doc_bin_train.to_disk("spacy-ner/train_data.spacy")
# Out:
# 100%|██████████| 28/28 [00:00<00:00, 838.30it/s]

# %%
doc_bin_test = build_docbin(test)
doc_bin_test.to_disk("spacy-ner/test_data.spacy")
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 677.57it/s]

# %% [markdown]
# ### Configuring SpaCy
# This step involves configuring SpaCy for your custom NER model involves initializing configuration files, and you can use a base configuration file as a template. To download the base_config.cfg file from the documentation, you can visit the official spaCy do cumentation website: https://spacy.io/usage/training#quickstart

# %% [markdown]
# ```
# # This is an auto-generated partial config. To use it with 'spacy train'
# # you can run spacy init fill-config to auto-fill all default settings:
# # python -m spacy init fill-config ./base_config.cfg ./config.cfg
# [paths]
# train = null
# dev = null
# vectors = null
# [system]
# gpu_allocator = null
#
# [nlp]
# lang = "en"
# pipeline = ["tok2vec","ner"]
# batch_size = 1000
#
# [components]
#
# [components.tok2vec]
# factory = "tok2vec"
#
# [components.tok2vec.model]
# @architectures = "spacy.Tok2Vec.v2"
#
# [components.tok2vec.model.embed]
# @architectures = "spacy.MultiHashEmbed.v2"
# width = ${components.tok2vec.model.encode.width}
# attrs = ["NORM", "PREFIX", "SUFFIX", "SHAPE"]
# rows = [5000, 1000, 2500, 2500]
# include_static_vectors = false
#
# [components.tok2vec.model.encode]
# @architectures = "spacy.MaxoutWindowEncoder.v2"
# width = 96
# depth = 4
# window_size = 1
# maxout_pieces = 3
#
# [components.ner]
# factory = "ner"
#
# [components.ner.model]
# @architectures = "spacy.TransitionBasedParser.v2"
# state_type = "ner"
# extra_state_tokens = false
# hidden_width = 64
# maxout_pieces = 2
# use_upper = true
# nO = null
#
# [components.ner.model.tok2vec]
# @architectures = "spacy.Tok2VecListener.v1"
# width = ${components.tok2vec.model.encode.width}
#
# [corpora]
#
# [corpora.train]
# @readers = "spacy.Corpus.v1"
# path = ${paths.train}
# max_length = 0
#
# [corpora.dev]
# @readers = "spacy.Corpus.v1"
# path = ${paths.dev}
# max_length = 0
#
# [training]
# dev_corpus = "corpora.dev"
# train_corpus = "corpora.train"
#
# [training.optimizer]
# @optimizers = "Adam.v1"
#
# [training.batcher]
# @batchers = "spacy.batch_by_words.v1"
# discard_oversize = false
# tolerance = 0.2
#
# [training.batcher.size]
# @schedules = "compounding.v1"
# start = 100
# stop = 1000
# compound = 1.001
#
# [initialize]
# vectors = ${paths.vectors}
# ```

# %% [markdown]
# After the base config we have to generate the full configuration file using `init-fill-config`

# %%
# !python -m spacy init fill-config spacy-ner/base_config.cfg spacy-ner/config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# spacy-ner/config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# Train the model as per config file

# %%
# !python -m spacy train spacy-ner/config.cfg  --output spacy-ner/trained_models  --paths.train spacy-ner/train_data.spacy  --paths.dev spacy-ner/test_data.spacy
# Out:
# ℹ Saving to output directory: spacy-ner/trained_models
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     26.44    0.00    0.00    0.00    0.00
#  12     200        799.77   2027.82   48.98   54.55   44.44    0.49
#  28     400       3981.22    152.19   57.14   63.64   51.85    0.57
#  48     600         42.06     24.65   62.22   77.78   51.85    0.62
#  73     800         23.79      6.42   59.09   76.47   48.15    0.59
# 105    1000        113.77     30.66   60.87   73.68   51.85    0.61
# 143    1200        177.65     15.50   45.83   52.38   40.74    0.46
# 192    1400        176.72     22.97   43.48   52.63   37.04    0.43
# 252    1600         81.58     16.37   41.67   47.62   37.04    0.42
# 318    1800        401.92     35.54   60.87   73.68   51.85    0.61
# 413    2000         59.85      9.43   58.33   66.67   51.85    0.58
# 513    2200         89.80     14.55   51.06   60.00   44.44    0.51
# ✔ Saved pipeline to output directory
# spacy-ner/trained_models/model-last

# %% [markdown]
# ### Inference

# %%
import spacy
nlp = spacy.load('spacy-ner/trained_models/model-best')
doc =  nlp('दुर्घटनालगत्तै उद्धार गरेर क्याप्टेन शाक्यलाई काठमाण्डु विमानस्थलबाट नजिकै रहेको नेपाल अस्पताल पुर्‍याइएको थियो ।')

for ent in doc.ents:
    print(ent.text, " => ", ent.label_)
# Out:
# क्याप्टेन  =>  POST
# शाक्यलाई  =>  PERSON
# नेपाल अस्पताल  =>  ORGANIZATION
