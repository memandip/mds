# %%
import pandas as pd

df = pd.read_csv('movie.csv')

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from scikit-learn) (2.2.5)
# Requirement already satisfied: scipy>=1.6.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mandipchaudhary/Desktop/mds/venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn.tree
import sklearn.preprocessing
import matplotlib.pyplot as plt

labelEncoder = sklearn.preprocessing.LabelEncoder()
fig, axes = plt.subplots(1, 2, layout='tight')
for i, name in enumerate(('popcorn', 'coke')):
    decisionTreeClassifier = sklearn.tree.DecisionTreeClassifier(
        criterion = 'gini',
        random_state = 42,
    )
    df_encoded = pd.DataFrame()
    df_encoded[name] = labelEncoder.fit_transform(df[name])
    decisionTreeClassifier.fit(X=df_encoded, y=df['watch'])
    sklearn.tree.plot_tree(
        decisionTreeClassifier,
        ax            = axes[i],
        feature_names = [name],
        filled        = True,
        class_names   = ['naah', 'watch'],
        rounded       = True,
        fontsize      = 14,
        node_ids      = True,
        # proportion    = True,
        # impurity      = False,
    )
plt.show()
# fig.savefig(f:='./py-sklearn-plt/movie-tree-1d.png'); return f
