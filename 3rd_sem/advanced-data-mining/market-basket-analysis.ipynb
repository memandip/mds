# %% [markdown]
# ## Market Basket Analysis

# %%
data = []
freq = dict.fromkeys({"bread", "butter", "breadNbutter"}, 0)

for i, items_col in data:
    items = set(items_col.split(","))
    print(i, items)
