# %% [markdown]
# ## Machine Learning

# %%
# Salaray prediction
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('data/Salary_Data.csv')
new_test_data = pd.DataFrame({
    'Age': [30],
    'Gender': ['Male'],
    'Education Level': ['Bachelor\'s'],
    'Job Title': ['Software Engineer'],
    'Years of Experience': [7],
    'Salary': [200000]
})
df = pd.concat([df, new_test_data], axis=0)
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (6705, 6)

# %%
df.iloc[6704]
# Out:
# Age                                 30.0
# Gender                              Male
# Education Level               Bachelor's
# Job Title              Software Engineer
# Years of Experience                  7.0
# Salary                          200000.0
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (6705, 6)

# %%
df.isna().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.dropna(inplace=True, axis=0)
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
numeric_cols = ["Age", "Years of Experience"]
categorical_cols = ["Gender", "Education Level", "Job Title"]
df_numeric = df[numeric_cols]
df_categorical = df[categorical_cols]
df_numeric.head()
# Out:
#     Age  Years of Experience
# 0  32.0                  5.0
# 1  28.0                  3.0
# 2  45.0                 15.0
# 3  36.0                  7.0
# 4  52.0                 20.0

# %%
df_categorical.head()
# Out:
#    Gender Education Level          Job Title
# 0    Male      Bachelor's  Software Engineer
# 1  Female        Master's       Data Analyst
# 2    Male             PhD     Senior Manager
# 3  Female      Bachelor's    Sales Associate
# 4    Male        Master's           Director

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df_categorical.head()
# Out:
#    Gender Education Level          Job Title
# 0    Male      Bachelor's  Software Engineer
# 1  Female        Master's       Data Analyst
# 2    Male             PhD     Senior Manager
# 3  Female      Bachelor's    Sales Associate
# 4    Male        Master's           Director

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df = pd.concat([df[numeric_cols], pd.get_dummies(df_categorical, drop_first=True), df[["Salary"]]], axis=1)
X = df.drop(columns=["Salary"], axis=1)
Y = df[["Salary"]]

# %%
test_data = X.iloc[[6698]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=15) # random_state=15 sets the seed to same values on each iteration

print(f"{X_train.shape}, {y_train.shape}")
# Out:
# (5359, 200), (5359, 1)

# %%
y_train.isna().sum()
# Out:
# Salary    0
# dtype: int64

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#        Age  Years of Experience  Gender_Male  Gender_Other  \
# 714   30.0                  5.0         True         False
# 3303  23.0                  1.0        False         False
# 1991  33.0                  6.0        False         False
# 3911  27.0                  3.0        False         False
# 2249  43.0                 14.0        False         False
#
#       Education Level_Bachelor's Degree  Education Level_High School  \
# 714                               False                        False
# 3303                               True                        False
# 1991                               True                        False
# 3911                              False                        False
# 2249                              False                        False
#
#       Education Level_Master's  Education Level_Master's Degree  \
# 714                      False                            False
# 3303                     False                            False
# 1991                     False                            False
# 3911                     False                             True
# 2249                     False                            False
#
#       Education Level_PhD  Education Level_phD  ...  \
# 714                 False                False  ...
# 3303                False                False  ...
# 1991                False                False  ...
# 3911                False                False  ...
# 2249                 True                False  ...
#
#       Job Title_Supply Chain Manager  Job Title_Technical Recruiter  \
# 714                            False                          False
# 3303                           False                          False
# 1991                           False                          False
# 3911                           False                          False
# 2249                           False                          False
#
#       Job Title_Technical Support Specialist  Job Title_Technical Writer  \
# 714                                    False                       False
# 3303                                   False                       False
# 1991                                   False                       False
# 3911                                   False                       False
# 2249                                   False                       False
#
#       Job Title_Training Specialist  Job Title_UX Designer  \
# 714                           False                  False
# 3303                          False                  False
# 1991                          False                  False
# 3911                          False                  False
# 2249                          False                  False
#
#       Job Title_UX Researcher  Job Title_VP of Finance  \
# 714                     False                    False
# 3303                    False                    False
# 1991                    False                    False
# 3911                    False                    False
# 2249                    False                    False
#
#       Job Title_VP of Operations  Job Title_Web Developer
# 714                        False                    False
# 3303                       False                    False
# 1991                       False                    False
# 3911                       False                    False
# 2249                       False                    False
#
# [5 rows x 200 columns]

# %%
predictions = lr_model.predict(X_test)
predictions
# Out:
# array([[138025.19423432],
#        [ 69894.0520657 ],
#        [107266.2641249 ],
#        ...,
#        [ 87164.60234121],
#        [ 95380.93228683],
#        [ 65457.23691278]])

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

def calculate_error(y_test, predictions):
    mse = mean_squared_error(y_test, predictions)
    rmse = root_mean_squared_error(y_test, predictions)
    mae = mean_absolute_error(y_test, predictions)
    mape = mean_absolute_percentage_error(y_test, predictions)

    print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}, MAPE: {mape:.4f}")
    return mse, rmse, mae, mape

# %%
# raw_errors = calculate_error(y_test, predictions)
preproessed_errors = calculate_error(y_test, predictions)
# Out:
# MSE: 324723116.5043, RMSE: 18020.0754, MAE: 12864.9841, MAPE: 0.1258

# %%
lr_model.predict(test_data.values)
# Out:
# /Users/admin/Desktop/MDS/ds-fundamentals/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[154490.4443299]])
